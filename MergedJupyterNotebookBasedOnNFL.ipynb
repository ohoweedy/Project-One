# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime as dt
import json
import os
import math
import statsmodels.api as sm


# Import API key
from project_one_api import mlb_api_key
from project_one_api import nfl_api_key
from project_one_api import nhl_api_key
from project_one_api import nba_api_key

# File to Load
nfl_payroll_file = "NFLFiles/nfl_payroll_new.csv"

# Read Purchasing File and store into Pandas data frame
nfl_payroll_data = pd.read_csv(nfl_payroll_file, encoding="utf-8")

# nfl_payroll_data['Payroll'] = nfl_payroll_data['Payroll'].str.replace(',', '')
# nfl_payroll_data['Payroll'] = nfl_payroll_data['Payroll'].str.replace('$', '')

# Convert columns from string to float
nfl_payroll_data['Year'] = nfl_payroll_data['Year'].astype(str)
nfl_payroll_data['Payroll'] = nfl_payroll_data['Payroll'].astype(float)

nfl_payroll_data = nfl_payroll_data[["Team","Year","Payroll","Relative Payroll"]]

nfl_payroll_data["Team"] = nfl_payroll_data["Year"] + nfl_payroll_data["Team"].map(str)

nfl_payroll_data = nfl_payroll_data[["Team", "Payroll", "Relative Payroll"]]
nfl_payroll_data["Relative Payroll"] = nfl_payroll_data["Relative Payroll"]*100

nfl_payroll_data.head()
# Out:
#             Team      Payroll  Relative Payroll
# 0    2014Falcons  175728823.0        128.092328
# 1     2014Browns  156240488.0        113.886883
# 2     2014Ravens  152294429.0        111.010520
# 3  2014Cardinals  151750413.0        110.613976
# 4   2014Seahawks  151634452.0        110.529449

# %%
### NFL STATS AND PAYROLL ###

nfl_pd = pd.DataFrame({"Team": [""], "Win Pct": [""], "Year": [""], "Points For": [""], "Points Against": [""], "Point Differential": [""]})

years = [2014, 2015, 2016, 2017, 2018]
nfl_all_data = []

for year in years:
    nfl_query_url = f"https://api.sportradar.us/nfl/official/trial/v5/en/seasons/{year}/standings.json?api_key={nfl_api_key}"
    nfl_standings_response = requests.get(nfl_query_url)
    time.sleep(2)
    nfl_standings = nfl_standings_response.json()
    nfl_all_data.append(nfl_standings)
        
# loop through each year        
for w in range(0, len(nfl_all_data)):
   #loop through division
    for z in range(0,len(nfl_all_data[w]['conferences'])):
        for y in range(0,len(nfl_all_data[w]['conferences'][z]['divisions'])): 
            for x in range(0,len(nfl_all_data[w]['conferences'][z]['divisions'][y]['teams'])):
                nfl_team_name = nfl_all_data[w]['conferences'][z]['divisions'][y]['teams'][x]['name']
                nfl_win_pct = nfl_all_data[w]['conferences'][z]['divisions'][y]['teams'][x]['win_pct']
                nfl_pts_for = nfl_all_data[w]['conferences'][z]['divisions'][y]['teams'][x]['points_for']
                nfl_pts_against = nfl_all_data[w]['conferences'][z]['divisions'][y]['teams'][x]['points_against']
                nfl_year = nfl_all_data[w]['season']['year']
                nfl_pd = nfl_pd.append({'Team' : nfl_team_name, 'Win Pct': nfl_win_pct, 'Year': nfl_year, 'Points For': nfl_pts_for, 
                                       'Points Against': nfl_pts_against}, ignore_index = True)
                
nfl_pd = nfl_pd.drop([0])

# Convert columns from string to float
nfl_pd['Year'] = nfl_pd['Year'].astype(str)
nfl_pd['Win Pct'] = nfl_pd['Win Pct'].astype(float)
nfl_pd['Points For'] = nfl_pd['Points For'].astype(float)
nfl_pd['Points Against'] = nfl_pd['Points Against'].astype(float)
nfl_pd['Point Differential'] = nfl_pd['Points For'] - nfl_pd['Points Against']

nfl_pd["Team"] = nfl_pd["Year"] + nfl_pd["Team"].map(str)

nfl_pd.head()
# Out:
#            Team  Win Pct  Year  Points For  Points Against  Point Differential
# 1  2014Patriots    0.750  2014       468.0           313.0               155.0
# 2     2014Bills    0.563  2014       343.0           289.0                54.0
# 3  2014Dolphins    0.500  2014       388.0           373.0                15.0
# 4      2014Jets    0.250  2014       283.0           401.0              -118.0
# 5  2014Steelers    0.688  2014       436.0           368.0                68.0

# %%
nfl_merged = pd.merge(nfl_pd, nfl_payroll_data, on='Team')
nfl_merged["Sport"] = "NFL"

nfl_merged.head()
# Out:
#            Team  Win Pct  Year  Points For  Points Against  \
# 0  2014Patriots    0.750  2014       468.0           313.0
# 1     2014Bills    0.563  2014       343.0           289.0
# 2  2014Dolphins    0.500  2014       388.0           373.0
# 3      2014Jets    0.250  2014       283.0           401.0
# 4  2014Steelers    0.688  2014       436.0           368.0
#
#    Point Differential      Payroll  Relative Payroll Sport
# 0               155.0  132130517.0         96.312633   NFL
# 1                54.0  135589765.0         98.834149   NFL
# 2                15.0  144645040.0        105.434724   NFL
# 3              -118.0  106085353.0         77.327781   NFL
# 4                68.0  138857568.0        101.216117   NFL

# %%
# Set x and y variables
x = nfl_merged["Relative Payroll"]
y = nfl_merged["Win Pct"]

# Build scatter plot
plt.scatter(x, y, marker="o", facecolors="green", edgecolors="black", alpha=0.8, linewidth=1, label="Relative Payroll v Win %")

plt.title(f"NFL Relative Payroll vs. Winning Percentage 2014 - 2018")
plt.xlabel("Relative Payroll")
plt.ylabel("Winning Percentage (%)")
plt.grid()

# Save image
plt.savefig("Images/NFL_plot.png")

# Show image
plt.show()

# %%
# Set x and y variables
y2 = nfl_merged["Point Differential"]

# Build scatter plot
plt.scatter(x, y2, marker="o", facecolors="orange", edgecolors="black", alpha=0.8, linewidth=1, label="Relative Payroll v Win %")

plt.title(f"NFL Relative Payroll vs. Point Differential 2014 - 2018")
plt.xlabel("Relative Payroll")
plt.ylabel("Point Differential")
plt.grid()


# Save image
plt.savefig("Images/NFL_plot2.png")

# Show image
plt.show()

# %%
nfl_newmerge_df = nfl_merged[["Team","Win Pct","Relative Payroll","Sport"]]
nfl_newmerge_df = nfl_newmerge_df.rename(columns={"Team": "TeamYear","Win Pct":"Win Ratio","Relative Payroll":"RelPayPerYear"})
nfl_newmerge_df.head(5)
# Out:
#        TeamYear  Win Ratio  RelPayPerYear Sport
# 0  2014Patriots      0.750      96.312633   NFL
# 1     2014Bills      0.563      98.834149   NFL
# 2  2014Dolphins      0.500     105.434724   NFL
# 3      2014Jets      0.250      77.327781   NFL
# 4  2014Steelers      0.688     101.216117   NFL

# %%
##Henry Starts Copying in NBA Code HERE

# %%
# We will attempt to get data on regular season wins and postseason wins for each team going back twenty years or 
#as long as the API has data for.  We are using sportsradar api

# %%
# Sportradar documentation: 

#This endpoint retrieves the current Standings.

# https://api.sportradar.us/nba/{access_level}/{version}/{language_code}/seasons/{season_year}/{nba_season}/
#standings.{format}?api_key={your_api_key}

# %%
# We will run a test first, but some of the items for the test will persist

# %%
#dependencies
from pprint import pprint
nba_csv_file = "NBAFiles/ProjectOne/NBASalaryDataCSV.csv"

# %%
nba_salary_df = pd.read_csv(nba_csv_file)

# %%
nba_salary_df
# Out:
#                  Team            Cap  Rank    YearMeanCap RelativePay
# 0           Bulls2018   $90,105,625      1  $110,191,023        81.8%
# 1            Suns2018   $92,518,634      2  $110,191,023        84.0%
# 2          Pacers2018   $93,661,969      3  $110,191,023        85.0%
# 3           Magic2018   $95,538,311      4  $110,191,023        86.7%
# 4            Nets2018   $95,964,560      5  $110,191,023        87.1%
# 5       Mavericks2018   $96,843,033      6  $110,191,023        87.9%
# 6           Kings2018   $97,154,206      7  $110,191,023        88.2%
# 7           76ers2018  $100,020,936      8  $110,191,023        90.8%
# 8           Hawks2018  $100,108,457      9  $110,191,023        90.8%
# 9          Lakers2018  $102,177,393     10  $110,191,023        92.7%
# 10         Knicks2018  $104,405,156     11  $110,191,023        94.7%
# 11           Heat2018  $105,065,917     12  $110,191,023        95.3%
# 12   Timberwolves2018  $105,179,927     13  $110,191,023        95.5%
# 13        Nuggets2018  $106,515,203     14  $110,191,023        96.7%
# 14           Jazz2018  $106,862,254     15  $110,191,023        97.0%
# 15      Grizzlies2018  $109,902,725     16  $110,191,023        99.7%
# 16        Celtics2018  $115,075,693     17  $110,191,023       104.4%
# 17         Spurts2018  $116,153,554     18  $110,191,023       105.4%
# 18          Bucks2018  $116,214,360     19  $110,191,023       105.5%
# 19        Raptors2018  $116,583,186     20  $110,191,023       105.8%
# 20        Hornets2018  $117,228,164     21  $110,191,023       106.4%
# 21        Rockets2018  $118,271,451     22  $110,191,023       107.3%
# 22       Pelicans2018  $118,813,359     23  $110,191,023       107.8%
# 23       Clippers2018  $118,817,049     24  $110,191,023       107.8%
# 24        Pistons2018  $118,897,722     25  $110,191,023       107.9%
# 25   Trailblazers2018  $119,265,261     26  $110,191,023       108.2%
# 26        Wizards2018  $124,114,043     27  $110,191,023       112.6%
# 27        Thunder2018  $132,920,346     28  $110,191,023       120.6%
# 28       Warriors2018  $135,371,746     29  $110,191,023       122.9%
# 29      Cavaliers2018  $135,980,450     30  $110,191,023       123.4%
# ..                ...            ...   ...            ...         ...
# 150          Suns2013   $53,234,902      1   $67,104,799        79.3%
# 151         Kings2013   $53,575,342      2   $67,104,799        79.8%
# 152       Rockets2013   $55,435,438      3   $67,104,799        82.6%
# 153       Hornets2013   $57,500,127      4   $67,104,799        85.7%
# 154  Trailblazers2013   $58,379,149      5   $67,104,799        87.0%
# 155       Wizards2013   $58,601,257      6   $67,104,799        87.3%
# 156         Bucks2013   $61,658,839      7   $67,104,799        91.9%
# 157     Mavericks2013   $61,941,526      8   $67,104,799        92.3%
# 158  Timberwolves2013   $62,360,135      9   $67,104,799        92.9%
# 159     Grizzlies2013   $63,276,388     10   $67,104,799        94.3%
# 160     Cavaliers2013   $63,587,875     11   $67,104,799        94.8%
# 161      Pelicans2013   $63,685,125     12   $67,104,799        94.9%
# 162       Nuggets2013   $63,970,222     13   $67,104,799        95.3%
# 163         76ers2013   $64,367,073     14   $67,104,799        95.9%
# 164         Magic2013   $66,215,396     15   $67,104,799        98.7%
# 165         Hawks2013   $66,492,527     16   $67,104,799        99.1%
# 166        Pacers2013   $66,745,868     17   $67,104,799        99.5%
# 167          Jazz2013   $66,913,862     18   $67,104,799        99.7%
# 168       Raptors2013   $68,081,026     19   $67,104,799       101.5%
# 169       Thunder2013   $68,257,854     20   $67,104,799       101.7%
# 170       Pistons2013   $68,565,736     21   $67,104,799       102.2%
# 171      Clippers2013   $69,518,889     22   $67,104,799       103.6%
# 172        Spurts2013   $69,568,331     23   $67,104,799       103.7%
# 173      Warriors2013   $69,712,825     24   $67,104,799       103.9%
# 174       Celtics2013   $71,576,087     25   $67,104,799       106.7%
# 175         Bulls2013   $74,258,448     26   $67,104,799       110.7%
# 176        Knicks2013   $78,854,599     27   $67,104,799       117.5%
# 177          Heat2013   $83,431,885     28   $67,104,799       124.3%
# 178          Nets2013   $83,529,674     29   $67,104,799       124.5%
# 179        Lakers2013   $99,847,565     30   $67,104,799       148.8%
#
# [180 rows x 5 columns]

# %%
nba_salary_df = nba_salary_df.rename(columns={"Team":"ConcatName"})
nba_salary_df.head()
# Out:
#    ConcatName           Cap  Rank    YearMeanCap RelativePay
# 0   Bulls2018  $90,105,625      1  $110,191,023        81.8%
# 1    Suns2018  $92,518,634      2  $110,191,023        84.0%
# 2  Pacers2018  $93,661,969      3  $110,191,023        85.0%
# 3   Magic2018  $95,538,311      4  $110,191,023        86.7%
# 4    Nets2018  $95,964,560      5  $110,191,023        87.1%

# %%
#Parameters


access_level = "trial"
version = "v5"
language_code = "en"
#Season year in Four Digit Format; Also, will need to make this a list when not in "test" mode
season_year = ["2013","2014","2015","2016","2017","2018"]
#nba_season refers to Pre, Regular, or Post; options are PRE, REG or PST
nba_season = "REG"
format_parameter = "json"
#need to remove key if it works
api_key = nba_api_key
base_url = "https://api.sportradar.us/nba/"

# %%
#print(kims_apikey)

# %%
#NBA Specific Info Needed for Queries:

# %%
# Lists to Hold Data

teams = []
division_list=[]
conference_list=[]
wins = []
losses = []
win_pct = []
points_for_list=[]
points_against_list=[]
cities = []
season_list =[]
regular_or_pst = []

# %%
nba_responses_dict = {}

# %%
#url assembly

#nba_url = f"{base_url}{access_level}/{version}/{language_code}/seasons/{season}/{nba_season}/standings/.{format_parameter}?api_key={api_key}"

#print(nba_url)

# %%
for season in season_year:
    #Finish URL 
    nba_url = f"{base_url}{access_level}/{version}/{language_code}/seasons/{season}/{nba_season}/standings.{format_parameter}?api_key={nba_api_key}"
    #print(nba_url)
    nba_response = requests.get(nba_url).json()
    time.sleep(2)
    nba_responses_dict[season]=nba_response
    season=season

# %%
#nba_responses_dict["2013"]

# %%
nba_responses_dict.keys()
# Out:
# dict_keys(['2013', '2014', '2015', '2016', '2017', '2018'])

# %%
pprint(nba_response)
# Out:
# {'conferences': [{'alias': 'WESTERN',
#                   'divisions': [{'alias': 'PACIFIC',
#                                  'id': 'f074cb3e-90cf-42e1-8067-cdbcd99ec230',
#                                  'name': 'Pacific',
#                                  'teams': [{'games_behind': {'conference': 0.0,
#                                                              'division': 0.0,
#                                                              'league': 4.5},
#                                             'id': '583ec825-fb46-11e1-82cb-f4ce4684ea4c',
#                                             'losses': 20,
#                                             'market': 'Golden State',
#                                             'name': 'Warriors',
#                                             'point_diff': 5.84,
#                                             'points_against': 112.38,
#                                             'points_for': 118.22,
#                                             'records': [{'losses': 4,
#                                                          'record_type': 'atlantic',
#                                                          'win_pct': 0.6,
#                                                          'wins': 6},
#                                                         {'losses': 5,
#                                                          'record_type': 'below_500',
#                                                          'win_pct': 0.762,
#                                                          'wins': 16},
#                                                         {'losses': 2,
#                                                          'record_type': 'central',
#                                                          'win_pct': 0.714,
#                                                          'wins': 5},
#                                                         {'losses': 12,
#                                                          'record_type': 'conference',
#                                                          'win_pct': 0.684,
#                                                          'wins': 26},
#                                                         {'losses': 2,
#                                                          'record_type': 'division',
#                                                          'win_pct': 0.846,
#                                                          'wins': 11},
#                                                         {'losses': 0,
#                                                          'record_type': 'equal_rebounds',
#                                                          'win_pct': 1.0,
#                                                          'wins': 2},
#                                                         {'losses': 3,
#                                                          'record_type': 'equal_turnovers',
#                                                          'win_pct': 0.25,
#                                                          'wins': 1},
#                                                         {'losses': 4,
#                                                          'record_type': 'fewer_turnovers',
#                                                          'win_pct': 0.857,
#                                                          'wins': 24},
#                                                         {'losses': 9,
#                                                          'record_type': 'home',
#                                                          'win_pct': 0.719,
#                                                          'wins': 23},
#                                                         {'losses': 5,
#                                                          'record_type': 'last_10',
#                                                          'win_pct': 0.5,
#                                                          'wins': 5},
#                                                         {'losses': 3,
#                                                          'record_type': 'last_10_home',
#                                                          'win_pct': 0.7,
#                                                          'wins': 7},
#                                                         {'losses': 3,
#                                                          'record_type': 'last_10_road',
#                                                          'win_pct': 0.7,
#                                                          'wins': 7},
#                                                         {'losses': 7,
#                                                          'record_type': 'leads_field_goal_pct',
#                                                          'win_pct': 0.844,
#                                                          'wins': 38},
#                                                         {'losses': 6,
#                                                          'record_type': 'leads_rebounds',
#                                                          'win_pct': 0.813,
#                                                          'wins': 26},
#                                                         {'losses': 5,
#                                                          'record_type': 'northwest',
#                                                          'win_pct': 0.615,
#                                                          'wins': 8},
#                                                         {'losses': 13,
#                                                          'record_type': 'opponent_fewer_turnovers',
#                                                          'win_pct': 0.594,
#                                                          'wins': 19},
#                                                         {'losses': 12,
#                                                          'record_type': 'opponent_leads_field_goal_pct',
#                                                          'win_pct': 0.294,
#                                                          'wins': 5},
#                                                         {'losses': 14,
#                                                          'record_type': 'opponent_leads_rebounds',
#                                                          'win_pct': 0.533,
#                                                          'wins': 16},
#                                                         {'losses': 20,
#                                                          'record_type': 'opponent_scores_100_or_more',
#                                                          'win_pct': 0.655,
#                                                          'wins': 38},
#                                                         {'losses': 4,
#                                                          'record_type': 'overtime',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 15,
#                                                          'record_type': 'over_500',
#                                                          'win_pct': 0.651,
#                                                          'wins': 28},
#                                                         {'losses': 2,
#                                                          'record_type': 'pacific',
#                                                          'win_pct': 0.846,
#                                                          'wins': 11},
#                                                         {'losses': 11,
#                                                          'record_type': 'road',
#                                                          'win_pct': 0.656,
#                                                          'wins': 21},
#                                                         {'losses': 13,
#                                                          'record_type': 'scores_100_or_more',
#                                                          'win_pct': 0.772,
#                                                          'wins': 44},
#                                                         {'losses': 2,
#                                                          'record_type': 'southeast',
#                                                          'win_pct': 0.778,
#                                                          'wins': 7},
#                                                         {'losses': 5,
#                                                          'record_type': 'southwest',
#                                                          'win_pct': 0.583,
#                                                          'wins': 7},
#                                                         {'losses': 8,
#                                                          'record_type': 'ten_points',
#                                                          'win_pct': 0.758,
#                                                          'wins': 25},
#                                                         {'losses': 6,
#                                                          'record_type': 'three_points',
#                                                          'win_pct': 0.5,
#                                                          'wins': 6}],
#                                             'reference': '1610612744',
#                                             'sr_id': 'sr:team:3428',
#                                             'streak': {'kind': 'loss',
#                                                        'length': 1},
#                                             'win_pct': 0.688,
#                                             'wins': 44},
#                                            {'games_behind': {'conference': 8.0,
#                                                              'division': 8.0,
#                                                              'league': 12.5},
#                                             'id': '583ecdfb-fb46-11e1-82cb-f4ce4684ea4c',
#                                             'losses': 29,
#                                             'market': 'Los Angeles',
#                                             'name': 'Clippers',
#                                             'point_diff': 0.68,
#                                             'points_against': 113.44,
#                                             'points_for': 114.12,
#                                             'records': [{'losses': 4,
#                                                          'record_type': 'atlantic',
#                                                          'win_pct': 0.429,
#                                                          'wins': 3},
#                                                         {'losses': 8,
#                                                          'record_type': 'below_500',
#                                                          'win_pct': 0.714,
#                                                          'wins': 20},
#                                                         {'losses': 2,
#                                                          'record_type': 'central',
#                                                          'win_pct': 0.6,
#                                                          'wins': 3},
#                                                         {'losses': 20,
#                                                          'record_type': 'conference',
#                                                          'win_pct': 0.545,
#                                                          'wins': 24},
#                                                         {'losses': 3,
#                                                          'record_type': 'division',
#                                                          'win_pct': 0.786,
#                                                          'wins': 11},
#                                                         {'losses': 1,
#                                                          'record_type': 'equal_rebounds',
#                                                          'win_pct': 0.5,
#                                                          'wins': 1},
#                                                         {'losses': 1,
#                                                          'record_type': 'equal_turnovers',
#                                                          'win_pct': 0.667,
#                                                          'wins': 2},
#                                                         {'losses': 10,
#                                                          'record_type': 'fewer_turnovers',
#                                                          'win_pct': 0.565,
#                                                          'wins': 13},
#                                                         {'losses': 12,
#                                                          'record_type': 'home',
#                                                          'win_pct': 0.6,
#                                                          'wins': 18},
#                                                         {'losses': 3,
#                                                          'record_type': 'last_10',
#                                                          'win_pct': 0.7,
#                                                          'wins': 7},
#                                                         {'losses': 6,
#                                                          'record_type': 'last_10_home',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 5,
#                                                          'record_type': 'last_10_road',
#                                                          'win_pct': 0.5,
#                                                          'wins': 5},
#                                                         {'losses': 8,
#                                                          'record_type': 'leads_field_goal_pct',
#                                                          'win_pct': 0.784,
#                                                          'wins': 29},
#                                                         {'losses': 7,
#                                                          'record_type': 'leads_rebounds',
#                                                          'win_pct': 0.781,
#                                                          'wins': 25},
#                                                         {'losses': 10,
#                                                          'record_type': 'northwest',
#                                                          'win_pct': 0.286,
#                                                          'wins': 4},
#                                                         {'losses': 18,
#                                                          'record_type': 'opponent_fewer_turnovers',
#                                                          'win_pct': 0.55,
#                                                          'wins': 22},
#                                                         {'losses': 20,
#                                                          'record_type': 'opponent_leads_field_goal_pct',
#                                                          'win_pct': 0.286,
#                                                          'wins': 8},
#                                                         {'losses': 21,
#                                                          'record_type': 'opponent_leads_rebounds',
#                                                          'win_pct': 0.344,
#                                                          'wins': 11},
#                                                         {'losses': 28,
#                                                          'record_type': 'opponent_scores_100_or_more',
#                                                          'win_pct': 0.525,
#                                                          'wins': 31},
#                                                         {'losses': 1,
#                                                          'record_type': 'overtime',
#                                                          'win_pct': 0.8,
#                                                          'wins': 4},
#                                                         {'losses': 21,
#                                                          'record_type': 'over_500',
#                                                          'win_pct': 0.447,
#                                                          'wins': 17},
#                                                         {'losses': 3,
#                                                          'record_type': 'pacific',
#                                                          'win_pct': 0.786,
#                                                          'wins': 11},
#                                                         {'losses': 17,
#                                                          'record_type': 'road',
#                                                          'win_pct': 0.528,
#                                                          'wins': 19},
#                                                         {'losses': 20,
#                                                          'record_type': 'scores_100_or_more',
#                                                          'win_pct': 0.649,
#                                                          'wins': 37},
#                                                         {'losses': 3,
#                                                          'record_type': 'southeast',
#                                                          'win_pct': 0.7,
#                                                          'wins': 7},
#                                                         {'losses': 7,
#                                                          'record_type': 'southwest',
#                                                          'win_pct': 0.563,
#                                                          'wins': 9},
#                                                         {'losses': 14,
#                                                          'record_type': 'ten_points',
#                                                          'win_pct': 0.563,
#                                                          'wins': 18},
#                                                         {'losses': 2,
#                                                          'record_type': 'three_points',
#                                                          'win_pct': 0.667,
#                                                          'wins': 4}],
#                                             'reference': '1610612746',
#                                             'sr_id': 'sr:team:3425',
#                                             'streak': {'kind': 'win',
#                                                        'length': 3},
#                                             'win_pct': 0.561,
#                                             'wins': 37},
#                                            {'games_behind': {'conference': 12.0,
#                                                              'division': 12.0,
#                                                              'league': 16.5},
#                                             'id': '583ed0ac-fb46-11e1-82cb-f4ce4684ea4c',
#                                             'losses': 32,
#                                             'market': 'Sacramento',
#                                             'name': 'Kings',
#                                             'point_diff': -1.23,
#                                             'points_against': 115.05,
#                                             'points_for': 113.81,
#                                             'records': [{'losses': 4,
#                                                          'record_type': 'atlantic',
#                                                          'win_pct': 0.333,
#                                                          'wins': 2},
#                                                         {'losses': 6,
#                                                          'record_type': 'below_500',
#                                                          'win_pct': 0.769,
#                                                          'wins': 20},
#                                                         {'losses': 3,
#                                                          'record_type': 'central',
#                                                          'win_pct': 0.625,
#                                                          'wins': 5},
#                                                         {'losses': 24,
#                                                          'record_type': 'conference',
#                                                          'win_pct': 0.415,
#                                                          'wins': 17},
#                                                         {'losses': 11,
#                                                          'record_type': 'division',
#                                                          'win_pct': 0.214,
#                                                          'wins': 3},
#                                                         {'losses': 1,
#                                                          'record_type': 'equal_rebounds',
#                                                          'win_pct': 0.667,
#                                                          'wins': 2},
#                                                         {'losses': 2,
#                                                          'record_type': 'equal_turnovers',
#                                                          'win_pct': 0.5,
#                                                          'wins': 2},
#                                                         {'losses': 21,
#                                                          'record_type': 'fewer_turnovers',
#                                                          'win_pct': 0.533,
#                                                          'wins': 24},
#                                                         {'losses': 14,
#                                                          'record_type': 'home',
#                                                          'win_pct': 0.588,
#                                                          'wins': 20},
#                                                         {'losses': 6,
#                                                          'record_type': 'last_10',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 4,
#                                                          'record_type': 'last_10_home',
#                                                          'win_pct': 0.6,
#                                                          'wins': 6},
#                                                         {'losses': 7,
#                                                          'record_type': 'last_10_road',
#                                                          'win_pct': 0.3,
#                                                          'wins': 3},
#                                                         {'losses': 7,
#                                                          'record_type': 'leads_field_goal_pct',
#                                                          'win_pct': 0.781,
#                                                          'wins': 25},
#                                                         {'losses': 8,
#                                                          'record_type': 'leads_rebounds',
#                                                          'win_pct': 0.652,
#                                                          'wins': 15},
#                                                         {'losses': 9,
#                                                          'record_type': 'northwest',
#                                                          'win_pct': 0.438,
#                                                          'wins': 7},
#                                                         {'losses': 9,
#                                                          'record_type': 'opponent_fewer_turnovers',
#                                                          'win_pct': 0.4,
#                                                          'wins': 6},
#                                                         {'losses': 25,
#                                                          'record_type': 'opponent_leads_field_goal_pct',
#                                                          'win_pct': 0.219,
#                                                          'wins': 7},
#                                                         {'losses': 23,
#                                                          'record_type': 'opponent_leads_rebounds',
#                                                          'win_pct': 0.395,
#                                                          'wins': 15},
#                                                         {'losses': 32,
#                                                          'record_type': 'opponent_scores_100_or_more',
#                                                          'win_pct': 0.418,
#                                                          'wins': 23},
#                                                         {'losses': 2,
#                                                          'record_type': 'overtime',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 26,
#                                                          'record_type': 'over_500',
#                                                          'win_pct': 0.316,
#                                                          'wins': 12},
#                                                         {'losses': 11,
#                                                          'record_type': 'pacific',
#                                                          'win_pct': 0.214,
#                                                          'wins': 3},
#                                                         {'losses': 18,
#                                                          'record_type': 'road',
#                                                          'win_pct': 0.4,
#                                                          'wins': 12},
#                                                         {'losses': 28,
#                                                          'record_type': 'scores_100_or_more',
#                                                          'win_pct': 0.517,
#                                                          'wins': 30},
#                                                         {'losses': 1,
#                                                          'record_type': 'southeast',
#                                                          'win_pct': 0.889,
#                                                          'wins': 8},
#                                                         {'losses': 4,
#                                                          'record_type': 'southwest',
#                                                          'win_pct': 0.636,
#                                                          'wins': 7},
#                                                         {'losses': 15,
#                                                          'record_type': 'ten_points',
#                                                          'win_pct': 0.464,
#                                                          'wins': 13},
#                                                         {'losses': 5,
#                                                          'record_type': 'three_points',
#                                                          'win_pct': 0.545,
#                                                          'wins': 6}],
#                                             'reference': '1610612758',
#                                             'sr_id': 'sr:team:3413',
#                                             'streak': {'kind': 'loss',
#                                                        'length': 1},
#                                             'win_pct': 0.5,
#                                             'wins': 32},
#                                            {'games_behind': {'conference': 14.5,
#                                                              'division': 14.5,
#                                                              'league': 19.0},
#                                             'id': '583ecae2-fb46-11e1-82cb-f4ce4684ea4c',
#                                             'losses': 35,
#                                             'market': 'Los Angeles',
#                                             'name': 'Lakers',
#                                             'point_diff': -1.83,
#                                             'points_against': 113.94,
#                                             'points_for': 112.11,
#                                             'records': [{'losses': 5,
#                                                          'record_type': 'atlantic',
#                                                          'win_pct': 0.167,
#                                                          'wins': 1},
#                                                         {'losses': 16,
#                                                          'record_type': 'below_500',
#                                                          'win_pct': 0.5,
#                                                          'wins': 16},
#                                                         {'losses': 3,
#                                                          'record_type': 'central',
#                                                          'win_pct': 0.571,
#                                                          'wins': 4},
#                                                         {'losses': 23,
#                                                          'record_type': 'conference',
#                                                          'win_pct': 0.477,
#                                                          'wins': 21},
#                                                         {'losses': 6,
#                                                          'record_type': 'division',
#                                                          'win_pct': 0.538,
#                                                          'wins': 7},
#                                                         {'losses': 1,
#                                                          'record_type': 'equal_rebounds',
#                                                          'win_pct': 0.667,
#                                                          'wins': 2},
#                                                         {'losses': 1,
#                                                          'record_type': 'equal_turnovers',
#                                                          'win_pct': 0.8,
#                                                          'wins': 4},
#                                                         {'losses': 10,
#                                                          'record_type': 'fewer_turnovers',
#                                                          'win_pct': 0.524,
#                                                          'wins': 11},
#                                                         {'losses': 15,
#                                                          'record_type': 'home',
#                                                          'win_pct': 0.545,
#                                                          'wins': 18},
#                                                         {'losses': 8,
#                                                          'record_type': 'last_10',
#                                                          'win_pct': 0.2,
#                                                          'wins': 2},
#                                                         {'losses': 6,
#                                                          'record_type': 'last_10_home',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 8,
#                                                          'record_type': 'last_10_road',
#                                                          'win_pct': 0.2,
#                                                          'wins': 2},
#                                                         {'losses': 15,
#                                                          'record_type': 'leads_field_goal_pct',
#                                                          'win_pct': 0.625,
#                                                          'wins': 25},
#                                                         {'losses': 12,
#                                                          'record_type': 'leads_rebounds',
#                                                          'win_pct': 0.647,
#                                                          'wins': 22},
#                                                         {'losses': 8,
#                                                          'record_type': 'northwest',
#                                                          'win_pct': 0.429,
#                                                          'wins': 6},
#                                                         {'losses': 24,
#                                                          'record_type': 'opponent_fewer_turnovers',
#                                                          'win_pct': 0.385,
#                                                          'wins': 15},
#                                                         {'losses': 20,
#                                                          'record_type': 'opponent_leads_field_goal_pct',
#                                                          'win_pct': 0.167,
#                                                          'wins': 4},
#                                                         {'losses': 22,
#                                                          'record_type': 'opponent_leads_rebounds',
#                                                          'win_pct': 0.214,
#                                                          'wins': 6},
#                                                         {'losses': 35,
#                                                          'record_type': 'opponent_scores_100_or_more',
#                                                          'win_pct': 0.397,
#                                                          'wins': 23},
#                                                         {'losses': 2,
#                                                          'record_type': 'overtime',
#                                                          'win_pct': 0.5,
#                                                          'wins': 2},
#                                                         {'losses': 19,
#                                                          'record_type': 'over_500',
#                                                          'win_pct': 0.424,
#                                                          'wins': 14},
#                                                         {'losses': 6,
#                                                          'record_type': 'pacific',
#                                                          'win_pct': 0.538,
#                                                          'wins': 7},
#                                                         {'losses': 20,
#                                                          'record_type': 'road',
#                                                          'win_pct': 0.375,
#                                                          'wins': 12},
#                                                         {'losses': 28,
#                                                          'record_type': 'scores_100_or_more',
#                                                          'win_pct': 0.509,
#                                                          'wins': 29},
#                                                         {'losses': 4,
#                                                          'record_type': 'southeast',
#                                                          'win_pct': 0.5,
#                                                          'wins': 4},
#                                                         {'losses': 9,
#                                                          'record_type': 'southwest',
#                                                          'win_pct': 0.471,
#                                                          'wins': 8},
#                                                         {'losses': 18,
#                                                          'record_type': 'ten_points',
#                                                          'win_pct': 0.4,
#                                                          'wins': 12},
#                                                         {'losses': 2,
#                                                          'record_type': 'three_points',
#                                                          'win_pct': 0.714,
#                                                          'wins': 5}],
#                                             'reference': '1610612747',
#                                             'sr_id': 'sr:team:3427',
#                                             'streak': {'kind': 'loss',
#                                                        'length': 4},
#                                             'win_pct': 0.462,
#                                             'wins': 30},
#                                            {'games_behind': {'conference': 30.0,
#                                                              'division': 30.0,
#                                                              'league': 34.5},
#                                             'id': '583ecfa8-fb46-11e1-82cb-f4ce4684ea4c',
#                                             'losses': 51,
#                                             'market': 'Phoenix',
#                                             'name': 'Suns',
#                                             'point_diff': -9.17,
#                                             'points_against': 115.82,
#                                             'points_for': 106.65,
#                                             'records': [{'losses': 7,
#                                                          'record_type': 'atlantic',
#                                                          'win_pct': 0.3,
#                                                          'wins': 3},
#                                                         {'losses': 19,
#                                                          'record_type': 'below_500',
#                                                          'win_pct': 0.24,
#                                                          'wins': 6},
#                                                         {'losses': 5,
#                                                          'record_type': 'central',
#                                                          'win_pct': 0.286,
#                                                          'wins': 2},
#                                                         {'losses': 32,
#                                                          'record_type': 'conference',
#                                                          'win_pct': 0.2,
#                                                          'wins': 8},
#                                                         {'losses': 12,
#                                                          'record_type': 'division',
#                                                          'win_pct': 0.143,
#                                                          'wins': 2},
#                                                         {'losses': 1,
#                                                          'record_type': 'equal_rebounds',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 3,
#                                                          'record_type': 'equal_turnovers',
#                                                          'win_pct': 0.25,
#                                                          'wins': 1},
#                                                         {'losses': 26,
#                                                          'record_type': 'fewer_turnovers',
#                                                          'win_pct': 0.235,
#                                                          'wins': 8},
#                                                         {'losses': 23,
#                                                          'record_type': 'home',
#                                                          'win_pct': 0.303,
#                                                          'wins': 10},
#                                                         {'losses': 6,
#                                                          'record_type': 'last_10',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 6,
#                                                          'record_type': 'last_10_home',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 9,
#                                                          'record_type': 'last_10_road',
#                                                          'win_pct': 0.1,
#                                                          'wins': 1},
#                                                         {'losses': 14,
#                                                          'record_type': 'leads_field_goal_pct',
#                                                          'win_pct': 0.5,
#                                                          'wins': 14},
#                                                         {'losses': 5,
#                                                          'record_type': 'leads_rebounds',
#                                                          'win_pct': 0.5,
#                                                          'wins': 5},
#                                                         {'losses': 12,
#                                                          'record_type': 'northwest',
#                                                          'win_pct': 0.143,
#                                                          'wins': 2},
#                                                         {'losses': 22,
#                                                          'record_type': 'opponent_fewer_turnovers',
#                                                          'win_pct': 0.214,
#                                                          'wins': 6},
#                                                         {'losses': 36,
#                                                          'record_type': 'opponent_leads_field_goal_pct',
#                                                          'win_pct': 0.027,
#                                                          'wins': 1},
#                                                         {'losses': 45,
#                                                          'record_type': 'opponent_leads_rebounds',
#                                                          'win_pct': 0.182,
#                                                          'wins': 10},
#                                                         {'losses': 50,
#                                                          'record_type': 'opponent_scores_100_or_more',
#                                                          'win_pct': 0.167,
#                                                          'wins': 10},
#                                                         {'losses': 3,
#                                                          'record_type': 'overtime',
#                                                          'win_pct': 0.25,
#                                                          'wins': 1},
#                                                         {'losses': 32,
#                                                          'record_type': 'over_500',
#                                                          'win_pct': 0.22,
#                                                          'wins': 9},
#                                                         {'losses': 12,
#                                                          'record_type': 'pacific',
#                                                          'win_pct': 0.143,
#                                                          'wins': 2},
#                                                         {'losses': 28,
#                                                          'record_type': 'road',
#                                                          'win_pct': 0.152,
#                                                          'wins': 5},
#                                                         {'losses': 33,
#                                                          'record_type': 'scores_100_or_more',
#                                                          'win_pct': 0.298,
#                                                          'wins': 14},
#                                                         {'losses': 7,
#                                                          'record_type': 'southeast',
#                                                          'win_pct': 0.222,
#                                                          'wins': 2},
#                                                         {'losses': 8,
#                                                          'record_type': 'southwest',
#                                                          'win_pct': 0.333,
#                                                          'wins': 4},
#                                                         {'losses': 33,
#                                                          'record_type': 'ten_points',
#                                                          'win_pct': 0.132,
#                                                          'wins': 5},
#                                                         {'losses': 4,
#                                                          'record_type': 'three_points',
#                                                          'win_pct': 0.5,
#                                                          'wins': 4}],
#                                             'reference': '1610612756',
#                                             'sr_id': 'sr:team:3416',
# ...
#                                                          'win_pct': 0.5,
#                                                          'wins': 5},
#                                                         {'losses': 5,
#                                                          'record_type': 'last_10_home',
#                                                          'win_pct': 0.5,
#                                                          'wins': 5},
#                                                         {'losses': 6,
#                                                          'record_type': 'last_10_road',
#                                                          'win_pct': 0.4,
#                                                          'wins': 4},
#                                                         {'losses': 4,
#                                                          'record_type': 'leads_field_goal_pct',
#                                                          'win_pct': 0.857,
#                                                          'wins': 24},
#                                                         {'losses': 15,
#                                                          'record_type': 'leads_rebounds',
#                                                          'win_pct': 0.605,
#                                                          'wins': 23},
#                                                         {'losses': 5,
#                                                          'record_type': 'northwest',
#                                                          'win_pct': 0.286,
#                                                          'wins': 2},
#                                                         {'losses': 24,
#                                                          'record_type': 'opponent_fewer_turnovers',
#                                                          'win_pct': 0.415,
#                                                          'wins': 17},
#                                                         {'losses': 28,
#                                                          'record_type': 'opponent_leads_field_goal_pct',
#                                                          'win_pct': 0.263,
#                                                          'wins': 10},
#                                                         {'losses': 16,
#                                                          'record_type': 'opponent_leads_rebounds',
#                                                          'win_pct': 0.407,
#                                                          'wins': 11},
#                                                         {'losses': 32,
#                                                          'record_type': 'opponent_scores_100_or_more',
#                                                          'win_pct': 0.439,
#                                                          'wins': 25},
#                                                         {'losses': 1,
#                                                          'record_type': 'overtime',
#                                                          'win_pct': 0.833,
#                                                          'wins': 5},
#                                                         {'losses': 18,
#                                                          'record_type': 'over_500',
#                                                          'win_pct': 0.419,
#                                                          'wins': 13},
#                                                         {'losses': 3,
#                                                          'record_type': 'pacific',
#                                                          'win_pct': 0.571,
#                                                          'wins': 4},
#                                                         {'losses': 17,
#                                                          'record_type': 'road',
#                                                          'win_pct': 0.452,
#                                                          'wins': 14},
#                                                         {'losses': 23,
#                                                          'record_type': 'scores_100_or_more',
#                                                          'win_pct': 0.589,
#                                                          'wins': 33},
#                                                         {'losses': 7,
#                                                          'record_type': 'southeast',
#                                                          'win_pct': 0.563,
#                                                          'wins': 9},
#                                                         {'losses': 5,
#                                                          'record_type': 'southwest',
#                                                          'win_pct': 0.5,
#                                                          'wins': 5},
#                                                         {'losses': 17,
#                                                          'record_type': 'ten_points',
#                                                          'win_pct': 0.414,
#                                                          'wins': 12},
#                                                         {'losses': 7,
#                                                          'record_type': 'three_points',
#                                                          'win_pct': 0.588,
#                                                          'wins': 10}],
#                                             'reference': '1610612751',
#                                             'sr_id': 'sr:team:3436',
#                                             'streak': {'kind': 'win',
#                                                        'length': 2},
#                                             'win_pct': 0.507,
#                                             'wins': 34},
#                                            {'games_behind': {'conference': 36.0,
#                                                              'division': 33.0,
#                                                              'league': 36.0},
#                                             'id': '583ec70e-fb46-11e1-82cb-f4ce4684ea4c',
#                                             'losses': 52,
#                                             'market': 'New York',
#                                             'name': 'Knicks',
#                                             'point_diff': -8.37,
#                                             'points_against': 114.2,
#                                             'points_for': 105.83,
#                                             'records': [{'losses': 12,
#                                                          'record_type': 'atlantic',
#                                                          'win_pct': 0.143,
#                                                          'wins': 2},
#                                                         {'losses': 23,
#                                                          'record_type': 'below_500',
#                                                          'win_pct': 0.179,
#                                                          'wins': 5},
#                                                         {'losses': 13,
#                                                          'record_type': 'central',
#                                                          'win_pct': 0.071,
#                                                          'wins': 1},
#                                                         {'losses': 35,
#                                                          'record_type': 'conference',
#                                                          'win_pct': 0.186,
#                                                          'wins': 8},
#                                                         {'losses': 12,
#                                                          'record_type': 'division',
#                                                          'win_pct': 0.143,
#                                                          'wins': 2},
#                                                         {'losses': 0,
#                                                          'record_type': 'equal_rebounds',
#                                                          'win_pct': 1.0,
#                                                          'wins': 1},
#                                                         {'losses': 5,
#                                                          'record_type': 'equal_turnovers',
#                                                          'win_pct': 0.286,
#                                                          'wins': 2},
#                                                         {'losses': 24,
#                                                          'record_type': 'fewer_turnovers',
#                                                          'win_pct': 0.2,
#                                                          'wins': 6},
#                                                         {'losses': 25,
#                                                          'record_type': 'home',
#                                                          'win_pct': 0.194,
#                                                          'wins': 6},
#                                                         {'losses': 7,
#                                                          'record_type': 'last_10',
#                                                          'win_pct': 0.3,
#                                                          'wins': 3},
#                                                         {'losses': 8,
#                                                          'record_type': 'last_10_home',
#                                                          'win_pct': 0.2,
#                                                          'wins': 2},
#                                                         {'losses': 9,
#                                                          'record_type': 'last_10_road',
#                                                          'win_pct': 0.1,
#                                                          'wins': 1},
#                                                         {'losses': 9,
#                                                          'record_type': 'leads_field_goal_pct',
#                                                          'win_pct': 0.5,
#                                                          'wins': 9},
#                                                         {'losses': 17,
#                                                          'record_type': 'leads_rebounds',
#                                                          'win_pct': 0.32,
#                                                          'wins': 8},
#                                                         {'losses': 7,
#                                                          'record_type': 'northwest',
#                                                          'win_pct': 0.0,
#                                                          'wins': 0},
#                                                         {'losses': 23,
#                                                          'record_type': 'opponent_fewer_turnovers',
#                                                          'win_pct': 0.179,
#                                                          'wins': 5},
#                                                         {'losses': 43,
#                                                          'record_type': 'opponent_leads_field_goal_pct',
#                                                          'win_pct': 0.085,
#                                                          'wins': 4},
#                                                         {'losses': 35,
#                                                          'record_type': 'opponent_leads_rebounds',
#                                                          'win_pct': 0.103,
#                                                          'wins': 4},
#                                                         {'losses': 51,
#                                                          'record_type': 'opponent_scores_100_or_more',
#                                                          'win_pct': 0.164,
#                                                          'wins': 10},
#                                                         {'losses': 1,
#                                                          'record_type': 'overtime',
#                                                          'win_pct': 0.667,
#                                                          'wins': 2},
#                                                         {'losses': 29,
#                                                          'record_type': 'over_500',
#                                                          'win_pct': 0.216,
#                                                          'wins': 8},
#                                                         {'losses': 6,
#                                                          'record_type': 'pacific',
#                                                          'win_pct': 0.143,
#                                                          'wins': 1},
#                                                         {'losses': 27,
#                                                          'record_type': 'road',
#                                                          'win_pct': 0.206,
#                                                          'wins': 7},
#                                                         {'losses': 34,
#                                                          'record_type': 'scores_100_or_more',
#                                                          'win_pct': 0.277,
#                                                          'wins': 13},
#                                                         {'losses': 10,
#                                                          'record_type': 'southeast',
#                                                          'win_pct': 0.333,
#                                                          'wins': 5},
#                                                         {'losses': 4,
#                                                          'record_type': 'southwest',
#                                                          'win_pct': 0.5,
#                                                          'wins': 4},
#                                                         {'losses': 31,
#                                                          'record_type': 'ten_points',
#                                                          'win_pct': 0.139,
#                                                          'wins': 5},
#                                                         {'losses': 7,
#                                                          'record_type': 'three_points',
#                                                          'win_pct': 0.222,
#                                                          'wins': 2}],
#                                             'reference': '1610612752',
#                                             'sr_id': 'sr:team:3421',
#                                             'streak': {'kind': 'loss',
#                                                        'length': 4},
#                                             'win_pct': 0.2,
#                                             'wins': 13}]}],
#                   'id': '3960cfac-7361-4b30-bc25-8d393de6f62f',
#                   'name': 'EASTERN CONFERENCE'}],
#  'league': {'alias': 'NBA',
#             'id': '4353138d-4c22-4396-95d8-5f587d2df25c',
#             'name': 'NBA'},
#  'season': {'id': '47c9979e-5c3f-453d-ac75-734d17412e3f',
#             'type': 'REG',
#             'year': 2018}}

# %%
# Will attempt to use multi-layered loops to minimize lines of code.  Our goal is to collect data for each team.
# To do this will attempt a team loop within a division loop within a conference loop. 

# THIS WHOLE THING PROBABLY NEEDS TO BE SHIFTED OVER and SUBMERGED UNDER THE SEASON LOOP  HOW TO DO?


for season in season_year:
    nba_response = nba_responses_dict[season]

    for conference in nba_response['conferences']:
        conference_name = conference['alias']
        print(f"Now analyzying teams in the {conference_name} conference")
        for division in conference["divisions"]:
            division_name = division['alias']
            print(f"Now analyzing teams in the {division_name} division of the {conference_name} conference")
            for team in division["teams"]:
                team_name = team['name']
                print(f"{team_name} is in the {division_name} division of the {conference_name} conference")
                teams.append(team_name)
                division_list.append(division_name)
                conference_list.append(conference_name)
                wins.append(team["wins"])
                losses.append(team["losses"])
                win_pct.append(team["win_pct"])
                points_for_list.append(team["points_for"])
                points_against_list.append(team["points_against"])
                cities.append(team['market'])
                season_list.append(season)
                team_count = len(teams)
                if nba_season == "REG":
                    regular_or_pst.append("Regular")
                    if nba_season == "PST":
                        regular_or_post.append("Playoffs")
                        #Need otherwise statement
            print(f"Team count is now {team_count}")
# Out:
# Now analyzying teams in the WESTERN conference
# Now analyzing teams in the PACIFIC division of the WESTERN conference
# Clippers is in the PACIFIC division of the WESTERN conference
# Warriors is in the PACIFIC division of the WESTERN conference
# Suns is in the PACIFIC division of the WESTERN conference
# Kings is in the PACIFIC division of the WESTERN conference
# Lakers is in the PACIFIC division of the WESTERN conference
# Team count is now 5
# Now analyzing teams in the SOUTHWEST division of the WESTERN conference
# Spurs is in the SOUTHWEST division of the WESTERN conference
# Rockets is in the SOUTHWEST division of the WESTERN conference
# Grizzlies is in the SOUTHWEST division of the WESTERN conference
# Mavericks is in the SOUTHWEST division of the WESTERN conference
# Pelicans is in the SOUTHWEST division of the WESTERN conference
# Team count is now 10
# Now analyzing teams in the NORTHWEST division of the WESTERN conference
# Thunder is in the NORTHWEST division of the WESTERN conference
# Trail Blazers is in the NORTHWEST division of the WESTERN conference
# Timberwolves is in the NORTHWEST division of the WESTERN conference
# Nuggets is in the NORTHWEST division of the WESTERN conference
# Jazz is in the NORTHWEST division of the WESTERN conference
# Team count is now 15
# Now analyzying teams in the EASTERN conference
# Now analyzing teams in the SOUTHEAST division of the EASTERN conference
# Heat is in the SOUTHEAST division of the EASTERN conference
# Wizards is in the SOUTHEAST division of the EASTERN conference
# Hornets is in the SOUTHEAST division of the EASTERN conference
# Hawks is in the SOUTHEAST division of the EASTERN conference
# Magic is in the SOUTHEAST division of the EASTERN conference
# Team count is now 20
# Now analyzing teams in the CENTRAL division of the EASTERN conference
# Pacers is in the CENTRAL division of the EASTERN conference
# Bulls is in the CENTRAL division of the EASTERN conference
# Cavaliers is in the CENTRAL division of the EASTERN conference
# Pistons is in the CENTRAL division of the EASTERN conference
# Bucks is in the CENTRAL division of the EASTERN conference
# Team count is now 25
# Now analyzing teams in the ATLANTIC division of the EASTERN conference
# Raptors is in the ATLANTIC division of the EASTERN conference
# Nets is in the ATLANTIC division of the EASTERN conference
# Knicks is in the ATLANTIC division of the EASTERN conference
# Celtics is in the ATLANTIC division of the EASTERN conference
# 76ers is in the ATLANTIC division of the EASTERN conference
# Team count is now 30
# Now analyzying teams in the EASTERN conference
# Now analyzing teams in the SOUTHEAST division of the EASTERN conference
# Hawks is in the SOUTHEAST division of the EASTERN conference
# Wizards is in the SOUTHEAST division of the EASTERN conference
# Heat is in the SOUTHEAST division of the EASTERN conference
# Hornets is in the SOUTHEAST division of the EASTERN conference
# Magic is in the SOUTHEAST division of the EASTERN conference
# Team count is now 35
# Now analyzing teams in the ATLANTIC division of the EASTERN conference
# Raptors is in the ATLANTIC division of the EASTERN conference
# Celtics is in the ATLANTIC division of the EASTERN conference
# Nets is in the ATLANTIC division of the EASTERN conference
# 76ers is in the ATLANTIC division of the EASTERN conference
# Knicks is in the ATLANTIC division of the EASTERN conference
# Team count is now 40
# Now analyzing teams in the CENTRAL division of the EASTERN conference
# Cavaliers is in the CENTRAL division of the EASTERN conference
# Bulls is in the CENTRAL division of the EASTERN conference
# Bucks is in the CENTRAL division of the EASTERN conference
# Pacers is in the CENTRAL division of the EASTERN conference
# Pistons is in the CENTRAL division of the EASTERN conference
# Team count is now 45
# Now analyzying teams in the WESTERN conference
# Now analyzing teams in the SOUTHWEST division of the WESTERN conference
# Rockets is in the SOUTHWEST division of the WESTERN conference
# Spurs is in the SOUTHWEST division of the WESTERN conference
# Grizzlies is in the SOUTHWEST division of the WESTERN conference
# Mavericks is in the SOUTHWEST division of the WESTERN conference
# Pelicans is in the SOUTHWEST division of the WESTERN conference
# Team count is now 50
# Now analyzing teams in the NORTHWEST division of the WESTERN conference
# Trail Blazers is in the NORTHWEST division of the WESTERN conference
# Thunder is in the NORTHWEST division of the WESTERN conference
# Jazz is in the NORTHWEST division of the WESTERN conference
# Nuggets is in the NORTHWEST division of the WESTERN conference
# Timberwolves is in the NORTHWEST division of the WESTERN conference
# Team count is now 55
# Now analyzing teams in the PACIFIC division of the WESTERN conference
# Warriors is in the PACIFIC division of the WESTERN conference
# Clippers is in the PACIFIC division of the WESTERN conference
# Suns is in the PACIFIC division of the WESTERN conference
# Kings is in the PACIFIC division of the WESTERN conference
# Lakers is in the PACIFIC division of the WESTERN conference
# Team count is now 60
# Now analyzying teams in the EASTERN conference
# Now analyzing teams in the CENTRAL division of the EASTERN conference
# Cavaliers is in the CENTRAL division of the EASTERN conference
# Pacers is in the CENTRAL division of the EASTERN conference
# Pistons is in the CENTRAL division of the EASTERN conference
# Bulls is in the CENTRAL division of the EASTERN conference
# Bucks is in the CENTRAL division of the EASTERN conference
# Team count is now 65
# Now analyzing teams in the ATLANTIC division of the EASTERN conference
# Raptors is in the ATLANTIC division of the EASTERN conference
# Celtics is in the ATLANTIC division of the EASTERN conference
# Knicks is in the ATLANTIC division of the EASTERN conference
# Nets is in the ATLANTIC division of the EASTERN conference
# 76ers is in the ATLANTIC division of the EASTERN conference
# Team count is now 70
# Now analyzing teams in the SOUTHEAST division of the EASTERN conference
# Hawks is in the SOUTHEAST division of the EASTERN conference
# Hornets is in the SOUTHEAST division of the EASTERN conference
# Heat is in the SOUTHEAST division of the EASTERN conference
# Wizards is in the SOUTHEAST division of the EASTERN conference
# Magic is in the SOUTHEAST division of the EASTERN conference
# Team count is now 75
# Now analyzying teams in the WESTERN conference
# Now analyzing teams in the PACIFIC division of the WESTERN conference
# Warriors is in the PACIFIC division of the WESTERN conference
# Clippers is in the PACIFIC division of the WESTERN conference
# Kings is in the PACIFIC division of the WESTERN conference
# Suns is in the PACIFIC division of the WESTERN conference
# Lakers is in the PACIFIC division of the WESTERN conference
# Team count is now 80
# Now analyzing teams in the NORTHWEST division of the WESTERN conference
# Thunder is in the NORTHWEST division of the WESTERN conference
# Trail Blazers is in the NORTHWEST division of the WESTERN conference
# Jazz is in the NORTHWEST division of the WESTERN conference
# Nuggets is in the NORTHWEST division of the WESTERN conference
# Timberwolves is in the NORTHWEST division of the WESTERN conference
# Team count is now 85
# Now analyzing teams in the SOUTHWEST division of the WESTERN conference
# Spurs is in the SOUTHWEST division of the WESTERN conference
# Grizzlies is in the SOUTHWEST division of the WESTERN conference
# Mavericks is in the SOUTHWEST division of the WESTERN conference
# Rockets is in the SOUTHWEST division of the WESTERN conference
# Pelicans is in the SOUTHWEST division of the WESTERN conference
# Team count is now 90
# Now analyzying teams in the EASTERN conference
# Now analyzing teams in the SOUTHEAST division of the EASTERN conference
# Wizards is in the SOUTHEAST division of the EASTERN conference
# Hawks is in the SOUTHEAST division of the EASTERN conference
# Heat is in the SOUTHEAST division of the EASTERN conference
# Hornets is in the SOUTHEAST division of the EASTERN conference
# Magic is in the SOUTHEAST division of the EASTERN conference
# Team count is now 95
# Now analyzing teams in the CENTRAL division of the EASTERN conference
# Cavaliers is in the CENTRAL division of the EASTERN conference
# Pacers is in the CENTRAL division of the EASTERN conference
# Bucks is in the CENTRAL division of the EASTERN conference
# Bulls is in the CENTRAL division of the EASTERN conference
# Pistons is in the CENTRAL division of the EASTERN conference
# Team count is now 100
# Now analyzing teams in the ATLANTIC division of the EASTERN conference
# Celtics is in the ATLANTIC division of the EASTERN conference
# Raptors is in the ATLANTIC division of the EASTERN conference
# Knicks is in the ATLANTIC division of the EASTERN conference
# 76ers is in the ATLANTIC division of the EASTERN conference
# Nets is in the ATLANTIC division of the EASTERN conference
# Team count is now 105
# Now analyzying teams in the WESTERN conference
# Now analyzing teams in the PACIFIC division of the WESTERN conference
# Warriors is in the PACIFIC division of the WESTERN conference
# Clippers is in the PACIFIC division of the WESTERN conference
# Kings is in the PACIFIC division of the WESTERN conference
# Lakers is in the PACIFIC division of the WESTERN conference
# Suns is in the PACIFIC division of the WESTERN conference
# Team count is now 110
# Now analyzing teams in the SOUTHWEST division of the WESTERN conference
# Spurs is in the SOUTHWEST division of the WESTERN conference
# Rockets is in the SOUTHWEST division of the WESTERN conference
# Grizzlies is in the SOUTHWEST division of the WESTERN conference
# Pelicans is in the SOUTHWEST division of the WESTERN conference
# Mavericks is in the SOUTHWEST division of the WESTERN conference
# Team count is now 115
# Now analyzing teams in the NORTHWEST division of the WESTERN conference
# Jazz is in the NORTHWEST division of the WESTERN conference
# Thunder is in the NORTHWEST division of the WESTERN conference
# Trail Blazers is in the NORTHWEST division of the WESTERN conference
# Nuggets is in the NORTHWEST division of the WESTERN conference
# Timberwolves is in the NORTHWEST division of the WESTERN conference
# Team count is now 120
# Now analyzying teams in the EASTERN conference
# Now analyzing teams in the SOUTHEAST division of the EASTERN conference
# Heat is in the SOUTHEAST division of the EASTERN conference
# Wizards is in the SOUTHEAST division of the EASTERN conference
# Hornets is in the SOUTHEAST division of the EASTERN conference
# Magic is in the SOUTHEAST division of the EASTERN conference
# Hawks is in the SOUTHEAST division of the EASTERN conference
# Team count is now 125
# Now analyzing teams in the ATLANTIC division of the EASTERN conference
# Raptors is in the ATLANTIC division of the EASTERN conference
# Celtics is in the ATLANTIC division of the EASTERN conference
# 76ers is in the ATLANTIC division of the EASTERN conference
# Knicks is in the ATLANTIC division of the EASTERN conference
# Nets is in the ATLANTIC division of the EASTERN conference
# Team count is now 130
# Now analyzing teams in the CENTRAL division of the EASTERN conference
# Cavaliers is in the CENTRAL division of the EASTERN conference
# Pacers is in the CENTRAL division of the EASTERN conference
# Bucks is in the CENTRAL division of the EASTERN conference
# Pistons is in the CENTRAL division of the EASTERN conference
# Bulls is in the CENTRAL division of the EASTERN conference
# Team count is now 135
# Now analyzying teams in the WESTERN conference
# Now analyzing teams in the PACIFIC division of the WESTERN conference
# Warriors is in the PACIFIC division of the WESTERN conference
# Clippers is in the PACIFIC division of the WESTERN conference
# Lakers is in the PACIFIC division of the WESTERN conference
# Kings is in the PACIFIC division of the WESTERN conference
# Suns is in the PACIFIC division of the WESTERN conference
# Team count is now 140
# Now analyzing teams in the SOUTHWEST division of the WESTERN conference
# Rockets is in the SOUTHWEST division of the WESTERN conference
# Pelicans is in the SOUTHWEST division of the WESTERN conference
# Spurs is in the SOUTHWEST division of the WESTERN conference
# Mavericks is in the SOUTHWEST division of the WESTERN conference
# Grizzlies is in the SOUTHWEST division of the WESTERN conference
# Team count is now 145
# Now analyzing teams in the NORTHWEST division of the WESTERN conference
# Trail Blazers is in the NORTHWEST division of the WESTERN conference
# Jazz is in the NORTHWEST division of the WESTERN conference
# Thunder is in the NORTHWEST division of the WESTERN conference
# Timberwolves is in the NORTHWEST division of the WESTERN conference
# Nuggets is in the NORTHWEST division of the WESTERN conference
# Team count is now 150
# Now analyzying teams in the WESTERN conference
# Now analyzing teams in the PACIFIC division of the WESTERN conference
# Warriors is in the PACIFIC division of the WESTERN conference
# Clippers is in the PACIFIC division of the WESTERN conference
# Kings is in the PACIFIC division of the WESTERN conference
# Lakers is in the PACIFIC division of the WESTERN conference
# Suns is in the PACIFIC division of the WESTERN conference
# Team count is now 155
# Now analyzing teams in the SOUTHWEST division of the WESTERN conference
# Rockets is in the SOUTHWEST division of the WESTERN conference
# Spurs is in the SOUTHWEST division of the WESTERN conference
# Pelicans is in the SOUTHWEST division of the WESTERN conference
# Mavericks is in the SOUTHWEST division of the WESTERN conference
# Grizzlies is in the SOUTHWEST division of the WESTERN conference
# Team count is now 160
# Now analyzing teams in the NORTHWEST division of the WESTERN conference
# Nuggets is in the NORTHWEST division of the WESTERN conference
# Thunder is in the NORTHWEST division of the WESTERN conference
# Trail Blazers is in the NORTHWEST division of the WESTERN conference
# Jazz is in the NORTHWEST division of the WESTERN conference
# Timberwolves is in the NORTHWEST division of the WESTERN conference
# Team count is now 165
# Now analyzying teams in the EASTERN conference
# Now analyzing teams in the SOUTHEAST division of the EASTERN conference
# Heat is in the SOUTHEAST division of the EASTERN conference
# Magic is in the SOUTHEAST division of the EASTERN conference
# Hornets is in the SOUTHEAST division of the EASTERN conference
# Wizards is in the SOUTHEAST division of the EASTERN conference
# Hawks is in the SOUTHEAST division of the EASTERN conference
# Team count is now 170
# Now analyzing teams in the CENTRAL division of the EASTERN conference
# Bucks is in the CENTRAL division of the EASTERN conference
# Pacers is in the CENTRAL division of the EASTERN conference
# Pistons is in the CENTRAL division of the EASTERN conference
# Bulls is in the CENTRAL division of the EASTERN conference
# Cavaliers is in the CENTRAL division of the EASTERN conference
# Team count is now 175
# Now analyzing teams in the ATLANTIC division of the EASTERN conference
# Raptors is in the ATLANTIC division of the EASTERN conference
# 76ers is in the ATLANTIC division of the EASTERN conference
# Celtics is in the ATLANTIC division of the EASTERN conference
# Nets is in the ATLANTIC division of the EASTERN conference
# Knicks is in the ATLANTIC division of the EASTERN conference
# Team count is now 180

# %%
season_list
# Out:
# ['2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2013', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2015', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018']

# %%
len(season_list)
# Out:
# 180

# %%
NBA_df = pd.DataFrame({"Season": season_list, "Regular Season or Playoffs": regular_or_pst,"City": cities,"Team": teams,"Conference": conference_list,"Division": division_list,"Wins": wins,"Losses": losses, "Win Pct.": win_pct,"Points For": points_for_list, "Points Against": points_against_list})

# %%
NBA_df
# Out:
#     Season Regular Season or Playoffs           City           Team  \
# 0     2013                    Regular    Los Angeles       Clippers
# 1     2013                    Regular   Golden State       Warriors
# 2     2013                    Regular        Phoenix           Suns
# 3     2013                    Regular     Sacramento          Kings
# 4     2013                    Regular    Los Angeles         Lakers
# 5     2013                    Regular    San Antonio          Spurs
# 6     2013                    Regular        Houston        Rockets
# 7     2013                    Regular        Memphis      Grizzlies
# 8     2013                    Regular         Dallas      Mavericks
# 9     2013                    Regular    New Orleans       Pelicans
# 10    2013                    Regular  Oklahoma City        Thunder
# 11    2013                    Regular       Portland  Trail Blazers
# 12    2013                    Regular      Minnesota   Timberwolves
# 13    2013                    Regular         Denver        Nuggets
# 14    2013                    Regular           Utah           Jazz
# 15    2013                    Regular          Miami           Heat
# 16    2013                    Regular     Washington        Wizards
# 17    2013                    Regular      Charlotte        Hornets
# 18    2013                    Regular        Atlanta          Hawks
# 19    2013                    Regular        Orlando          Magic
# 20    2013                    Regular        Indiana         Pacers
# 21    2013                    Regular        Chicago          Bulls
# 22    2013                    Regular      Cleveland      Cavaliers
# 23    2013                    Regular        Detroit        Pistons
# 24    2013                    Regular      Milwaukee          Bucks
# 25    2013                    Regular        Toronto        Raptors
# 26    2013                    Regular       Brooklyn           Nets
# 27    2013                    Regular       New York         Knicks
# 28    2013                    Regular         Boston        Celtics
# 29    2013                    Regular   Philadelphia          76ers
# ..     ...                        ...            ...            ...
# 150   2018                    Regular   Golden State       Warriors
# 151   2018                    Regular    Los Angeles       Clippers
# 152   2018                    Regular     Sacramento          Kings
# 153   2018                    Regular    Los Angeles         Lakers
# 154   2018                    Regular        Phoenix           Suns
# 155   2018                    Regular        Houston        Rockets
# 156   2018                    Regular    San Antonio          Spurs
# 157   2018                    Regular    New Orleans       Pelicans
# 158   2018                    Regular         Dallas      Mavericks
# 159   2018                    Regular        Memphis      Grizzlies
# 160   2018                    Regular         Denver        Nuggets
# 161   2018                    Regular  Oklahoma City        Thunder
# 162   2018                    Regular       Portland  Trail Blazers
# 163   2018                    Regular           Utah           Jazz
# 164   2018                    Regular      Minnesota   Timberwolves
# 165   2018                    Regular          Miami           Heat
# 166   2018                    Regular        Orlando          Magic
# 167   2018                    Regular      Charlotte        Hornets
# 168   2018                    Regular     Washington        Wizards
# 169   2018                    Regular        Atlanta          Hawks
# 170   2018                    Regular      Milwaukee          Bucks
# 171   2018                    Regular        Indiana         Pacers
# 172   2018                    Regular        Detroit        Pistons
# 173   2018                    Regular        Chicago          Bulls
# 174   2018                    Regular      Cleveland      Cavaliers
# 175   2018                    Regular        Toronto        Raptors
# 176   2018                    Regular   Philadelphia          76ers
# 177   2018                    Regular         Boston        Celtics
# 178   2018                    Regular       Brooklyn           Nets
# 179   2018                    Regular       New York         Knicks
#
#     Conference   Division  Wins  Losses  Win Pct.  Points For  Points Against
# 0      WESTERN    PACIFIC    57      25     0.695      107.93          100.95
# 1      WESTERN    PACIFIC    51      31     0.622      104.26           99.45
# 2      WESTERN    PACIFIC    48      34     0.585      105.23          102.60
# 3      WESTERN    PACIFIC    28      54     0.341      100.50          103.40
# 4      WESTERN    PACIFIC    27      55     0.329      102.95          109.24
# 5      WESTERN  SOUTHWEST    62      20     0.756      105.35           97.63
# 6      WESTERN  SOUTHWEST    54      28     0.659      107.67          103.11
# 7      WESTERN  SOUTHWEST    50      32     0.610       96.15           94.57
# 8      WESTERN  SOUTHWEST    49      33     0.598      104.84          102.44
# 9      WESTERN  SOUTHWEST    34      48     0.415       99.72          102.43
# 10     WESTERN  NORTHWEST    59      23     0.720      106.16           99.82
# 11     WESTERN  NORTHWEST    54      28     0.659      106.74          102.76
# 12     WESTERN  NORTHWEST    40      42     0.488      106.93          104.26
# 13     WESTERN  NORTHWEST    36      46     0.439      104.38          106.52
# 14     WESTERN  NORTHWEST    25      57     0.305       95.01          102.18
# 15     EASTERN  SOUTHEAST    54      28     0.659      102.20           97.44
# 16     EASTERN  SOUTHEAST    44      38     0.537      100.66           99.39
# 17     EASTERN  SOUTHEAST    43      39     0.524       96.85           97.07
# 18     EASTERN  SOUTHEAST    38      44     0.463      101.00          101.48
# 19     EASTERN  SOUTHEAST    23      59     0.280       96.51          101.95
# 20     EASTERN    CENTRAL    56      26     0.683       96.74           92.34
# 21     EASTERN    CENTRAL    48      34     0.585       93.66           91.81
# 22     EASTERN    CENTRAL    33      49     0.402       98.22          101.51
# 23     EASTERN    CENTRAL    29      53     0.354      101.05          104.71
# 24     EASTERN    CENTRAL    15      67     0.183       95.48          103.66
# 25     EASTERN   ATLANTIC    48      34     0.585      101.28           98.04
# 26     EASTERN   ATLANTIC    44      38     0.537       98.52           99.52
# 27     EASTERN   ATLANTIC    37      45     0.451       98.59           99.38
# 28     EASTERN   ATLANTIC    25      57     0.305       96.24          100.71
# 29     EASTERN   ATLANTIC    19      63     0.232       99.45          109.90
# ..         ...        ...   ...     ...       ...         ...             ...
# 150    WESTERN    PACIFIC    44      20     0.688      118.22          112.38
# 151    WESTERN    PACIFIC    37      29     0.561      114.12          113.44
# 152    WESTERN    PACIFIC    32      32     0.500      113.81          115.05
# 153    WESTERN    PACIFIC    30      35     0.462      112.11          113.94
# 154    WESTERN    PACIFIC    15      51     0.227      106.65          115.82
# 155    WESTERN  SOUTHWEST    39      25     0.609      113.33          110.84
# 156    WESTERN  SOUTHWEST    37      29     0.561      111.88          110.96
# 157    WESTERN  SOUTHWEST    30      37     0.448      115.79          115.02
# 158    WESTERN  SOUTHWEST    27      37     0.422      108.17          109.83
# 159    WESTERN  SOUTHWEST    26      40     0.394      101.38          103.82
# 160    WESTERN  NORTHWEST    43      21     0.672      112.11          107.03
# 161    WESTERN  NORTHWEST    39      25     0.609      115.31          111.20
# 162    WESTERN  NORTHWEST    39      25     0.609      113.56          110.16
# 163    WESTERN  NORTHWEST    37      27     0.578      110.30          106.80
# 164    WESTERN  NORTHWEST    30      35     0.462      112.86          113.15
# 165    EASTERN  SOUTHEAST    30      34     0.469      105.75          106.20
# 166    EASTERN  SOUTHEAST    30      36     0.455      105.86          106.82
# 167    EASTERN  SOUTHEAST    29      35     0.453      110.78          111.41
# 168    EASTERN  SOUTHEAST    27      37     0.422      114.33          117.00
# 169    EASTERN  SOUTHEAST    22      44     0.333      112.14          118.85
# 170    EASTERN    CENTRAL    48      16     0.750      117.30          108.23
# 171    EASTERN    CENTRAL    42      23     0.646      108.69          103.72
# 172    EASTERN    CENTRAL    32      31     0.508      107.76          107.91
# 173    EASTERN    CENTRAL    19      47     0.288      104.92          112.41
# 174    EASTERN    CENTRAL    16      49     0.246      103.65          113.29
# 175    EASTERN   ATLANTIC    46      19     0.708      113.88          108.83
# 176    EASTERN   ATLANTIC    41      24     0.631      115.40          112.11
# 177    EASTERN   ATLANTIC    40      26     0.606      112.18          106.61
# 178    EASTERN   ATLANTIC    34      33     0.507      111.93          112.30
# 179    EASTERN   ATLANTIC    13      52     0.200      105.83          114.20
#
# [180 rows x 11 columns]

# %%
NBA_df["ConcatName"]=NBA_df["Team"]+NBA_df["Season"].map(str)

# %%
NBA_df
# Out:
#     Season Regular Season or Playoffs           City           Team  \
# 0     2013                    Regular    Los Angeles       Clippers
# 1     2013                    Regular   Golden State       Warriors
# 2     2013                    Regular        Phoenix           Suns
# 3     2013                    Regular     Sacramento          Kings
# 4     2013                    Regular    Los Angeles         Lakers
# 5     2013                    Regular    San Antonio          Spurs
# 6     2013                    Regular        Houston        Rockets
# 7     2013                    Regular        Memphis      Grizzlies
# 8     2013                    Regular         Dallas      Mavericks
# 9     2013                    Regular    New Orleans       Pelicans
# 10    2013                    Regular  Oklahoma City        Thunder
# 11    2013                    Regular       Portland  Trail Blazers
# 12    2013                    Regular      Minnesota   Timberwolves
# 13    2013                    Regular         Denver        Nuggets
# 14    2013                    Regular           Utah           Jazz
# 15    2013                    Regular          Miami           Heat
# 16    2013                    Regular     Washington        Wizards
# 17    2013                    Regular      Charlotte        Hornets
# 18    2013                    Regular        Atlanta          Hawks
# 19    2013                    Regular        Orlando          Magic
# 20    2013                    Regular        Indiana         Pacers
# 21    2013                    Regular        Chicago          Bulls
# 22    2013                    Regular      Cleveland      Cavaliers
# 23    2013                    Regular        Detroit        Pistons
# 24    2013                    Regular      Milwaukee          Bucks
# 25    2013                    Regular        Toronto        Raptors
# 26    2013                    Regular       Brooklyn           Nets
# 27    2013                    Regular       New York         Knicks
# 28    2013                    Regular         Boston        Celtics
# 29    2013                    Regular   Philadelphia          76ers
# ..     ...                        ...            ...            ...
# 150   2018                    Regular   Golden State       Warriors
# 151   2018                    Regular    Los Angeles       Clippers
# 152   2018                    Regular     Sacramento          Kings
# 153   2018                    Regular    Los Angeles         Lakers
# 154   2018                    Regular        Phoenix           Suns
# 155   2018                    Regular        Houston        Rockets
# 156   2018                    Regular    San Antonio          Spurs
# 157   2018                    Regular    New Orleans       Pelicans
# 158   2018                    Regular         Dallas      Mavericks
# 159   2018                    Regular        Memphis      Grizzlies
# 160   2018                    Regular         Denver        Nuggets
# 161   2018                    Regular  Oklahoma City        Thunder
# 162   2018                    Regular       Portland  Trail Blazers
# 163   2018                    Regular           Utah           Jazz
# 164   2018                    Regular      Minnesota   Timberwolves
# 165   2018                    Regular          Miami           Heat
# 166   2018                    Regular        Orlando          Magic
# 167   2018                    Regular      Charlotte        Hornets
# 168   2018                    Regular     Washington        Wizards
# 169   2018                    Regular        Atlanta          Hawks
# 170   2018                    Regular      Milwaukee          Bucks
# 171   2018                    Regular        Indiana         Pacers
# 172   2018                    Regular        Detroit        Pistons
# 173   2018                    Regular        Chicago          Bulls
# 174   2018                    Regular      Cleveland      Cavaliers
# 175   2018                    Regular        Toronto        Raptors
# 176   2018                    Regular   Philadelphia          76ers
# 177   2018                    Regular         Boston        Celtics
# 178   2018                    Regular       Brooklyn           Nets
# 179   2018                    Regular       New York         Knicks
#
#     Conference   Division  Wins  Losses  Win Pct.  Points For  Points Against  \
# 0      WESTERN    PACIFIC    57      25     0.695      107.93          100.95
# 1      WESTERN    PACIFIC    51      31     0.622      104.26           99.45
# 2      WESTERN    PACIFIC    48      34     0.585      105.23          102.60
# 3      WESTERN    PACIFIC    28      54     0.341      100.50          103.40
# 4      WESTERN    PACIFIC    27      55     0.329      102.95          109.24
# 5      WESTERN  SOUTHWEST    62      20     0.756      105.35           97.63
# 6      WESTERN  SOUTHWEST    54      28     0.659      107.67          103.11
# 7      WESTERN  SOUTHWEST    50      32     0.610       96.15           94.57
# 8      WESTERN  SOUTHWEST    49      33     0.598      104.84          102.44
# 9      WESTERN  SOUTHWEST    34      48     0.415       99.72          102.43
# 10     WESTERN  NORTHWEST    59      23     0.720      106.16           99.82
# 11     WESTERN  NORTHWEST    54      28     0.659      106.74          102.76
# 12     WESTERN  NORTHWEST    40      42     0.488      106.93          104.26
# 13     WESTERN  NORTHWEST    36      46     0.439      104.38          106.52
# 14     WESTERN  NORTHWEST    25      57     0.305       95.01          102.18
# 15     EASTERN  SOUTHEAST    54      28     0.659      102.20           97.44
# 16     EASTERN  SOUTHEAST    44      38     0.537      100.66           99.39
# 17     EASTERN  SOUTHEAST    43      39     0.524       96.85           97.07
# 18     EASTERN  SOUTHEAST    38      44     0.463      101.00          101.48
# 19     EASTERN  SOUTHEAST    23      59     0.280       96.51          101.95
# 20     EASTERN    CENTRAL    56      26     0.683       96.74           92.34
# 21     EASTERN    CENTRAL    48      34     0.585       93.66           91.81
# 22     EASTERN    CENTRAL    33      49     0.402       98.22          101.51
# 23     EASTERN    CENTRAL    29      53     0.354      101.05          104.71
# 24     EASTERN    CENTRAL    15      67     0.183       95.48          103.66
# 25     EASTERN   ATLANTIC    48      34     0.585      101.28           98.04
# 26     EASTERN   ATLANTIC    44      38     0.537       98.52           99.52
# 27     EASTERN   ATLANTIC    37      45     0.451       98.59           99.38
# 28     EASTERN   ATLANTIC    25      57     0.305       96.24          100.71
# 29     EASTERN   ATLANTIC    19      63     0.232       99.45          109.90
# ..         ...        ...   ...     ...       ...         ...             ...
# 150    WESTERN    PACIFIC    44      20     0.688      118.22          112.38
# 151    WESTERN    PACIFIC    37      29     0.561      114.12          113.44
# 152    WESTERN    PACIFIC    32      32     0.500      113.81          115.05
# 153    WESTERN    PACIFIC    30      35     0.462      112.11          113.94
# 154    WESTERN    PACIFIC    15      51     0.227      106.65          115.82
# 155    WESTERN  SOUTHWEST    39      25     0.609      113.33          110.84
# 156    WESTERN  SOUTHWEST    37      29     0.561      111.88          110.96
# 157    WESTERN  SOUTHWEST    30      37     0.448      115.79          115.02
# 158    WESTERN  SOUTHWEST    27      37     0.422      108.17          109.83
# 159    WESTERN  SOUTHWEST    26      40     0.394      101.38          103.82
# 160    WESTERN  NORTHWEST    43      21     0.672      112.11          107.03
# 161    WESTERN  NORTHWEST    40      25     0.615      115.52          111.35
# 162    WESTERN  NORTHWEST    39      26     0.600      113.68          110.45
# 163    WESTERN  NORTHWEST    37      27     0.578      110.30          106.80
# 164    WESTERN  NORTHWEST    30      35     0.462      112.86          113.15
# 165    EASTERN  SOUTHEAST    30      34     0.469      105.75          106.20
# 166    EASTERN  SOUTHEAST    30      36     0.455      105.86          106.82
# 167    EASTERN  SOUTHEAST    29      35     0.453      110.78          111.41
# 168    EASTERN  SOUTHEAST    27      37     0.422      114.33          117.00
# 169    EASTERN  SOUTHEAST    22      44     0.333      112.14          118.85
# 170    EASTERN    CENTRAL    49      16     0.754      117.29          108.08
# 171    EASTERN    CENTRAL    42      24     0.636      108.53          103.92
# 172    EASTERN    CENTRAL    32      31     0.508      107.76          107.91
# 173    EASTERN    CENTRAL    19      47     0.288      104.92          112.41
# 174    EASTERN    CENTRAL    16      49     0.246      103.65          113.29
# 175    EASTERN   ATLANTIC    46      19     0.708      113.88          108.83
# 176    EASTERN   ATLANTIC    41      24     0.631      115.40          112.11
# 177    EASTERN   ATLANTIC    40      26     0.606      112.18          106.61
# 178    EASTERN   ATLANTIC    34      33     0.507      111.93          112.30
# 179    EASTERN   ATLANTIC    13      52     0.200      105.83          114.20
#
#             ConcatName
# 0         Clippers2013
# 1         Warriors2013
# 2             Suns2013
# 3            Kings2013
# 4           Lakers2013
# 5            Spurs2013
# 6          Rockets2013
# 7        Grizzlies2013
# 8        Mavericks2013
# 9         Pelicans2013
# 10         Thunder2013
# 11   Trail Blazers2013
# 12    Timberwolves2013
# 13         Nuggets2013
# 14            Jazz2013
# 15            Heat2013
# 16         Wizards2013
# 17         Hornets2013
# 18           Hawks2013
# 19           Magic2013
# 20          Pacers2013
# 21           Bulls2013
# 22       Cavaliers2013
# 23         Pistons2013
# 24           Bucks2013
# 25         Raptors2013
# 26            Nets2013
# 27          Knicks2013
# 28         Celtics2013
# 29           76ers2013
# ..                 ...
# 150       Warriors2018
# 151       Clippers2018
# 152          Kings2018
# 153         Lakers2018
# 154           Suns2018
# 155        Rockets2018
# 156          Spurs2018
# 157       Pelicans2018
# 158      Mavericks2018
# 159      Grizzlies2018
# 160        Nuggets2018
# 161        Thunder2018
# 162  Trail Blazers2018
# 163           Jazz2018
# 164   Timberwolves2018
# 165           Heat2018
# 166          Magic2018
# 167        Hornets2018
# 168        Wizards2018
# 169          Hawks2018
# 170          Bucks2018
# 171         Pacers2018
# 172        Pistons2018
# 173          Bulls2018
# 174      Cavaliers2018
# 175        Raptors2018
# 176          76ers2018
# 177        Celtics2018
# 178           Nets2018
# 179         Knicks2018
#
# [180 rows x 12 columns]

# %%
nba_combined_df =pd.merge(NBA_df,nba_salary_df,on="ConcatName")

# %%
nba_combined_df.head()
# Out:
#   Season Regular Season or Playoffs          City      Team Conference  \
# 0   2013                    Regular   Los Angeles  Clippers    WESTERN
# 1   2013                    Regular  Golden State  Warriors    WESTERN
# 2   2013                    Regular       Phoenix      Suns    WESTERN
# 3   2013                    Regular    Sacramento     Kings    WESTERN
# 4   2013                    Regular   Los Angeles    Lakers    WESTERN
#
#   Division  Wins  Losses  Win Pct.  Points For  Points Against    ConcatName  \
# 0  PACIFIC    57      25     0.695      107.93          100.95  Clippers2013
# 1  PACIFIC    51      31     0.622      104.26           99.45  Warriors2013
# 2  PACIFIC    48      34     0.585      105.23          102.60      Suns2013
# 3  PACIFIC    28      54     0.341      100.50          103.40     Kings2013
# 4  PACIFIC    27      55     0.329      102.95          109.24    Lakers2013
#
#             Cap  Rank   YearMeanCap RelativePay
# 0  $69,518,889     22  $67,104,799       103.6%
# 1  $69,712,825     24  $67,104,799       103.9%
# 2  $53,234,902      1  $67,104,799        79.3%
# 3  $53,575,342      2  $67,104,799        79.8%
# 4  $99,847,565     30  $67,104,799       148.8%

# %%
nba_combined_df = nba_combined_df.replace(to_replace="%", value='',regex=True)

# %%
nba_combined_df.head()
# Out:
#   Season Regular Season or Playoffs          City      Team Conference  \
# 0   2013                    Regular   Los Angeles  Clippers    WESTERN
# 1   2013                    Regular  Golden State  Warriors    WESTERN
# 2   2013                    Regular       Phoenix      Suns    WESTERN
# 3   2013                    Regular    Sacramento     Kings    WESTERN
# 4   2013                    Regular   Los Angeles    Lakers    WESTERN
#
#   Division  Wins  Losses  Win Pct.  Points For  Points Against    ConcatName  \
# 0  PACIFIC    57      25     0.695      107.93          100.95  Clippers2013
# 1  PACIFIC    51      31     0.622      104.26           99.45  Warriors2013
# 2  PACIFIC    48      34     0.585      105.23          102.60      Suns2013
# 3  PACIFIC    28      54     0.341      100.50          103.40     Kings2013
# 4  PACIFIC    27      55     0.329      102.95          109.24    Lakers2013
#
#             Cap  Rank   YearMeanCap RelativePay
# 0  $69,518,889     22  $67,104,799        103.6
# 1  $69,712,825     24  $67,104,799        103.9
# 2  $53,234,902      1  $67,104,799         79.3
# 3  $53,575,342      2  $67,104,799         79.8
# 4  $99,847,565     30  $67,104,799        148.8

# %%
nba_combined_df["RelativePay"] = nba_combined_df["RelativePay"].astype(float)

# %%
nba_combined_df["Sport"] = "NBA"

# %%
nba_combined_df.head()
# Out:
#   Season Regular Season or Playoffs          City      Team Conference  \
# 0   2013                    Regular   Los Angeles  Clippers    WESTERN
# 1   2013                    Regular  Golden State  Warriors    WESTERN
# 2   2013                    Regular       Phoenix      Suns    WESTERN
# 3   2013                    Regular    Sacramento     Kings    WESTERN
# 4   2013                    Regular   Los Angeles    Lakers    WESTERN
#
#   Division  Wins  Losses  Win Pct.  Points For  Points Against    ConcatName  \
# 0  PACIFIC    57      25     0.695      107.93          100.95  Clippers2013
# 1  PACIFIC    51      31     0.622      104.26           99.45  Warriors2013
# 2  PACIFIC    48      34     0.585      105.23          102.60      Suns2013
# 3  PACIFIC    28      54     0.341      100.50          103.40     Kings2013
# 4  PACIFIC    27      55     0.329      102.95          109.24    Lakers2013
#
#             Cap  Rank   YearMeanCap  RelativePay Sport
# 0  $69,518,889     22  $67,104,799         103.6   NBA
# 1  $69,712,825     24  $67,104,799         103.9   NBA
# 2  $53,234,902      1  $67,104,799          79.3   NBA
# 3  $53,575,342      2  $67,104,799          79.8   NBA
# 4  $99,847,565     30  $67,104,799         148.8   NBA

# %%
nba_combined_df.dtypes
# Out:
# Season                         object
# Regular Season or Playoffs     object
# City                           object
# Team                           object
# Conference                     object
# Division                       object
# Wins                            int64
# Losses                          int64
# Win Pct.                      float64
# Points For                    float64
# Points Against                float64
# ConcatName                     object
# Cap                            object
# Rank                            int64
# YearMeanCap                    object
# RelativePay                   float64
# Sport                          object
# dtype: object

# %%
x_axis = nba_combined_df["RelativePay"]
y_axis = nba_combined_df['Win Pct.']

# %%
#new df for merge
nba_newmerge_df = nba_combined_df[["ConcatName","Win Pct.","RelativePay","Sport"]]
nba_newmerge_df = nba_newmerge_df.rename(columns={"ConcatName":"TeamYear","Win Pct.":"Win Ratio","RelativePay":"RelPayPerYear"})
nba_newmerge_df.head(5)
# Out:
#        TeamYear  Win Ratio  RelPayPerYear Sport
# 0  Clippers2013      0.695          103.6   NBA
# 1  Warriors2013      0.622          103.9   NBA
# 2      Suns2013      0.585           79.3   NBA
# 3     Kings2013      0.341           79.8   NBA
# 4    Lakers2013      0.329          148.8   NBA

# %%
plt.scatter(x_axis,y_axis,marker="o",color="r",edgecolor="black")
plt.savefig("NBA Winning Percentage vs Relative Pay")

# %%
from scipy.stats import linregress

# %%
linregress(x_axis,y_axis)
# Out:
# LinregressResult(slope=0.0018764514823312731, intercept=0.30279951093689933, rvalue=0.16332274208901545, pvalue=0.03440231131943612, stderr=0.0008797630632623427)

# %%
##Eric's Part

# %%
#MLB
sal_path = "MLBFiles/TotPayroll.csv"
mlb_sal_df = pd.read_csv(sal_path)
mlb_sal_df.head(5)
# Out:
#              Team Name Team Name.1     TeamYear  Roster  25-Man Payroll  \
# 0       Boston Red Sox     Red Sox  Red Sox2019      39       202597500
# 1         Chicago Cubs        Cubs     Cubs2019      40       206825714
# 2     New York Yankees     Yankees  Yankees2019      40       196146071
# 3  Los Angeles Dodgers     Dodgers  Dodgers2019      40       148660002
# 4   Los Angeles Angels      Angels   Angels2019      39       164949999
#
#         IR  Retained   Buried Suspended  Total Payroll  RelPayPerYear  Year
# 0        -  19000000        -         -      221042500     175.365114  2019
# 1   575000         -        -   3400000      210800714     167.239744  2019
# 2        -   2000000        -         -      198146071     157.200123  2019
# 3        -  39116666  5000000         -      192776668     152.940282  2019
# 4  1901000    500000        -         -      167350999     132.768707  2019

# %%
years = [2013,2014,2015,2016,2017,2018]
access_level = "t" 
version = 6
mlb_season = "REG"
format = "json" 
your_api_key = mlb_api_key
all_mlb = []
for year in years:
    response = requests.get(
        url=f"https://api.sportradar.us/mlb-{access_level}{version}/seasontd/{year}/{mlb_season}/standings.{format}?api_key={mlb_api_key}"
    )
    response = response.json()
    all_mlb.append(response)
    time.sleep(1)

# %%
mlb_team_names = []
mlb_win_ratio = []
mlb_year = []
#loop through east/west
for w in range(0,len(all_mlb)):
    for z in range(0,len(all_mlb[w]['league']['season']['leagues'])):
        #loop through division
        for y in range(0,len(all_mlb[w]['league']['season']['leagues'][z]['divisions'])):
            #loop through each team
            for x in range(0,len(all_mlb[w]['league']['season']['leagues'][z]['divisions'][y]['teams'])):
                mlb_team_names.append(all_mlb[w]['league']['season']['leagues'][z]['divisions'][y]['teams'][x]['name'])
                mlb_win_ratio.append(all_mlb[w]['league']['season']['leagues'][z]['divisions'][y]['teams'][x]['win_p'])
                mlb_year.append(all_mlb[w]['league']['season']['year'])

# %%
mlb_df = pd.DataFrame({
    "Team Name": mlb_team_names,
    "Win Ratio": mlb_win_ratio,
    "MLB Year": mlb_year,
    "Sport":"MLB"
})
mlb_df["TeamYear"] = mlb_df["Team Name"] + mlb_df["MLB Year"].map(str)
mlb_df = mlb_df[["TeamYear", "Win Ratio","Sport"]]
mlb_df.head(5)
# Out:
#            TeamYear  Win Ratio Sport
# 0       Dodgers2013      0.568   MLB
# 1  Diamondbacks2013      0.500   MLB
# 2        Giants2013      0.469   MLB
# 3        Padres2013      0.469   MLB
# 4       Rockies2013      0.457   MLB

# %%
mlb_merged_df = pd.merge(mlb_df, mlb_sal_df, on ="TeamYear")
mlb_merged_df.head(5)
# Out:
#            TeamYear  Win Ratio Sport             Team Name   Team Name.1  \
# 0       Dodgers2013      0.568   MLB   Los Angeles Dodgers       Dodgers
# 1  Diamondbacks2013      0.500   MLB  Arizona Diamondbacks  Diamondbacks
# 2        Giants2013      0.469   MLB  San Francisco Giants        Giants
# 3        Padres2013      0.469   MLB      San Diego Padres        Padres
# 4       Rockies2013      0.457   MLB      Colorado Rockies       Rockies
#
#    Roster  25-Man Payroll       IR  Retained   Buried Suspended  \
# 0      39       207344759   505000  25747116  7977500         -
# 1      33        75126043  3000000   9916749  2947500         -
# 2      37       135382980  2498000   2157977   490500         -
# 3      40        63615894   605000   8875201  1472800         -
# 4      39        74020354        -   1459705  4265500         -
#
#    Total Payroll  RelPayPerYear  Year
# 0      239894375     216.401218  2013
# 1       88316478      79.667535  2013
# 2      140280186     126.542371  2013
# 3       73286341      66.109318  2013
# 4       79271624      71.508454  2013

# %%
mlb_merged_df = mlb_merged_df[["TeamYear","Win Ratio","RelPayPerYear","Sport"]]
mlb_merged_df.head(5)
# Out:
#            TeamYear  Win Ratio  RelPayPerYear Sport
# 0       Dodgers2013      0.568     216.401218   MLB
# 1  Diamondbacks2013      0.500      79.667535   MLB
# 2        Giants2013      0.469     126.542371   MLB
# 3        Padres2013      0.469      66.109318   MLB
# 4       Rockies2013      0.457      71.508454   MLB

# %%
plt.scatter(mlb_merged_df["Win Ratio"],mlb_merged_df["RelPayPerYear"])
plt.xlabel("Win Ratio")
plt.ylabel("Total Payroll (10 Mil)")
plt.title("Total Payroll vs Win Ratio")
plt.grid()

# %%
access_level = "trial"
version = "v6"
language_code = "en"
nhl_years = [2013,2014,2015,2016,2017,2018]
nhl_season = "REG"
format = "json"

nhl_data = []
for year in nhl_years:
    response = requests.get(
        url=f"https://api.sportradar.us/nhl/{access_level}/{version}/{language_code}/seasons/{year}/{nhl_season}/standings.{format}?api_key={nhl_api_key}"
    )
    response = response.json()
    nhl_data.append(response)
    time.sleep(1)

# %%
nhl_team_names = []
nhl_win_ratio = []
nhl_year = []
nhl_p_dif = []
#loop through east/west
for w in range(0,len(nhl_data)):
    for z in range(0,len(nhl_data[w]['conferences'])):
        #loop through division
        for y in range(0,len(nhl_data[w]['conferences'][z]['divisions'])):
            #loop through each team
            for x in range(0,len(nhl_data[w]['conferences'][z]['divisions'][y]['teams'])):
                nhl_team_names.append(nhl_data[w]['conferences'][z]['divisions'][y]['teams'][x]['name'])
                nhl_win_ratio.append(nhl_data[w]['conferences'][z]['divisions'][y]['teams'][x]['win_pct'])
                nhl_year.append(nhl_data[w]['season']['year'])
                nhl_p_dif.append(nhl_data[w]['conferences'][z]['divisions'][y]['teams'][x]['goal_diff'])

# %%
nhl_df = pd.DataFrame({
    "Team Name": nhl_team_names,
    "Win Ratio": nhl_win_ratio,
    "NHL Year": nhl_year,
    "Goal Diff": nhl_p_dif,
    "Sport": "NHL"
})
nhl_df["TeamYear"] = nhl_df["Team Name"] + nhl_df["NHL Year"].map(str)
nhl_df = nhl_df[["TeamYear", "Win Ratio","Goal Diff","Sport"]]
nhl_df.head(5)
# Out:
#          TeamYear  Win Ratio  Goal Diff Sport
# 0   Avalanche2013      0.634         30   NHL
# 1       Blues2013      0.634         57   NHL
# 2  Blackhawks2013      0.561         47   NHL
# 3        Wild2013      0.524          1   NHL
# 4       Stars2013      0.488          7   NHL

# %%
nhl_sal_path = "NHLFiles/NHLcap.csv"
nhl_sal_df = pd.read_csv(nhl_sal_path)

# %%
nhl_merged_df = pd.merge(nhl_df, nhl_sal_df, on ="TeamYear")

# %%
nhl_merged_df.head(5)

# %%
nhl_merged_df = nhl_merged_df[["TeamYear","Win Ratio","RelTotPay","Sport"]]
nhl_merged_df = nhl_merged_df.rename(columns = {"RelTotPay": "RelPayPerYear"})
nhl_merged_df.head(5)
# Out:
#          TeamYear  Win Ratio  RelPayPerYear Sport
# 0   Avalanche2013      0.634      97.066279   NHL
# 1       Blues2013      0.634      99.810437   NHL
# 2  Blackhawks2013      0.561     119.278289   NHL
# 3       Stars2013      0.488      75.777388   NHL
# 4   Predators2013      0.463      83.692067   NHL

# %%
plt.scatter(nhl_merged_df["Win Ratio"],nhl_merged_df["RelPayPerYear"])
plt.xlabel("Win Ratio")
plt.ylabel("NHL Total Payroll (1 Mil)")
plt.title("NHL Total Payroll vs Win Ratio")
plt.grid()

# %%
all_sports_df = pd.concat([mlb_merged_df,nhl_merged_df,nba_newmerge_df,nfl_newmerge_df])
all_sports_df.head()
gb_sports_df = all_sports_df.groupby("Sport")
gb_sports_df.head(5)
# Out:
#            TeamYear  Win Ratio  RelPayPerYear Sport
# 0       Dodgers2013      0.568     216.401218   MLB
# 1  Diamondbacks2013      0.500      79.667535   MLB
# 2        Giants2013      0.469     126.542371   MLB
# 3        Padres2013      0.469      66.109318   MLB
# 4       Rockies2013      0.457      71.508454   MLB
# 0     Avalanche2013      0.634      97.066279   NHL
# 1         Blues2013      0.634      99.810437   NHL
# 2    Blackhawks2013      0.561     119.278289   NHL
# 3         Stars2013      0.488      75.777388   NHL
# 4     Predators2013      0.463      83.692067   NHL
# 0      Clippers2013      0.695     103.600000   NBA
# 1      Warriors2013      0.622     103.900000   NBA
# 2          Suns2013      0.585      79.300000   NBA
# 3         Kings2013      0.341      79.800000   NBA
# 4        Lakers2013      0.329     148.800000   NBA
# 0      2014Patriots      0.750      96.312633   NFL
# 1         2014Bills      0.563      98.834149   NFL
# 2      2014Dolphins      0.500     105.434724   NFL
# 3          2014Jets      0.250      77.327781   NFL
# 4      2014Steelers      0.688     101.216117   NFL

# %%
plt.scatter(all_sports_df["RelPayPerYear"],all_sports_df["Win Ratio"],alpha=0.50)
plt.xlabel("Relative Pay Per Year (%)")
plt.ylabel("Win Ratio")
plt.title("All Sports Total Payroll vs Win Ratio")
plt.grid()

# %%
#mlb_merged_df,nhl_merged_df,nba_newmerge_df,nfl_newmerge_df
plt.scatter(mlb_merged_df["RelPayPerYear"],mlb_merged_df["Win Ratio"],alpha=0.25,color="r")
plt.scatter(nhl_merged_df["RelPayPerYear"],nhl_merged_df["Win Ratio"],alpha=0.25,color="skyblue")
plt.scatter(nba_newmerge_df["RelPayPerYear"],nba_newmerge_df["Win Ratio"],alpha=0.25,color="b")
plt.scatter(nfl_newmerge_df["RelPayPerYear"],nfl_newmerge_df["Win Ratio"],alpha=0.25,color="g")
plt.xlabel("Relative Pay Per Year (%)")
plt.ylabel("Win Ratio")
plt.title("All Sports Total Payroll vs Win Ratio")
plt.grid()

# %%
#Stats
#X = df["RM"]
# y = target["MEDV"]

# # Note the difference in argument order
# model = sm.OLS(y, X).fit()
# predictions = model.predict(X) # make the predictions by the model

# # Print out the statistics
# model.summary()

X = all_sports_df["RelPayPerYear"]
y = all_sports_df["Win Ratio"]
model = sm.OLS(y,X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Win Ratio   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     6415.
# Date:                Fri, 08 Mar 2019   Prob (F-statistic):               0.00
# Time:                        19:38:14   Log-Likelihood:                 284.76
# No. Observations:                 684   AIC:                            -567.5
# Df Residuals:                     683   BIC:                            -563.0
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# RelPayPerYear     0.0048   5.98e-05     80.093      0.000       0.005       0.005
# ==============================================================================
# Omnibus:                       20.348   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.590
# Skew:                          -0.370   Prob(JB):                     1.24e-05
# Kurtosis:                       3.495   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
####  Working with Point Differential

# %%
nba_combined_df.head()
# Out:
#   Season Regular Season or Playoffs          City      Team Conference  \
# 0   2013                    Regular   Los Angeles  Clippers    WESTERN
# 1   2013                    Regular  Golden State  Warriors    WESTERN
# 2   2013                    Regular       Phoenix      Suns    WESTERN
# 3   2013                    Regular    Sacramento     Kings    WESTERN
# 4   2013                    Regular   Los Angeles    Lakers    WESTERN
#
#   Division  Wins  Losses  Win Pct.  Points For  Points Against    ConcatName  \
# 0  PACIFIC    57      25     0.695      107.93          100.95  Clippers2013
# 1  PACIFIC    51      31     0.622      104.26           99.45  Warriors2013
# 2  PACIFIC    48      34     0.585      105.23          102.60      Suns2013
# 3  PACIFIC    28      54     0.341      100.50          103.40     Kings2013
# 4  PACIFIC    27      55     0.329      102.95          109.24    Lakers2013
#
#             Cap  Rank   YearMeanCap  RelativePay Sport
# 0  $69,518,889     22  $67,104,799         103.6   NBA
# 1  $69,712,825     24  $67,104,799         103.9   NBA
# 2  $53,234,902      1  $67,104,799          79.3   NBA
# 3  $53,575,342      2  $67,104,799          79.8   NBA
# 4  $99,847,565     30  $67,104,799         148.8   NBA

# %%
nba_combined_df["Point Diff"] = nba_combined_df["Points For"] - nba_combined_df["Points Against"]

# %%
nba_combined_df.head()
# Out:
#   Season Regular Season or Playoffs          City      Team Conference  \
# 0   2013                    Regular   Los Angeles  Clippers    WESTERN
# 1   2013                    Regular  Golden State  Warriors    WESTERN
# 2   2013                    Regular       Phoenix      Suns    WESTERN
# 3   2013                    Regular    Sacramento     Kings    WESTERN
# 4   2013                    Regular   Los Angeles    Lakers    WESTERN
#
#   Division  Wins  Losses  Win Pct.  Points For  Points Against    ConcatName  \
# 0  PACIFIC    57      25     0.695      107.93          100.95  Clippers2013
# 1  PACIFIC    51      31     0.622      104.26           99.45  Warriors2013
# 2  PACIFIC    48      34     0.585      105.23          102.60      Suns2013
# 3  PACIFIC    28      54     0.341      100.50          103.40     Kings2013
# 4  PACIFIC    27      55     0.329      102.95          109.24    Lakers2013
#
#             Cap  Rank   YearMeanCap  RelativePay Sport  Point Diff
# 0  $69,518,889     22  $67,104,799         103.6   NBA        6.98
# 1  $69,712,825     24  $67,104,799         103.9   NBA        4.81
# 2  $53,234,902      1  $67,104,799          79.3   NBA        2.63
# 3  $53,575,342      2  $67,104,799          79.8   NBA       -2.90
# 4  $99,847,565     30  $67,104,799         148.8   NBA       -6.29

# %%
nfl_merged.head()
# Out:
#            Team  Win Pct  Year  Points For  Points Against  \
# 0  2014Patriots    0.750  2014       468.0           313.0
# 1     2014Bills    0.563  2014       343.0           289.0
# 2  2014Dolphins    0.500  2014       388.0           373.0
# 3      2014Jets    0.250  2014       283.0           401.0
# 4  2014Steelers    0.688  2014       436.0           368.0
#
#    Point Differential      Payroll  Relative Payroll Sport
# 0               155.0  132130517.0         96.312633   NFL
# 1                54.0  135589765.0         98.834149   NFL
# 2                15.0  144645040.0        105.434724   NFL
# 3              -118.0  106085353.0         77.327781   NFL
# 4                68.0  138857568.0        101.216117   NFL

# %%
nfl_merged["Point Diff per Game"]= nfl_merged["Point Differential"]/16

# %%
nfl_merged.head()
# Out:
#            Team  Win Pct  Year  Points For  Points Against  \
# 0  2014Patriots    0.750  2014       468.0           313.0
# 1     2014Bills    0.563  2014       343.0           289.0
# 2  2014Dolphins    0.500  2014       388.0           373.0
# 3      2014Jets    0.250  2014       283.0           401.0
# 4  2014Steelers    0.688  2014       436.0           368.0
#
#    Point Differential      Payroll  Relative Payroll Sport  \
# 0               155.0  132130517.0         96.312633   NFL
# 1                54.0  135589765.0         98.834149   NFL
# 2                15.0  144645040.0        105.434724   NFL
# 3              -118.0  106085353.0         77.327781   NFL
# 4                68.0  138857568.0        101.216117   NFL
#
#    Point Diff per Game
# 0               9.6875
# 1               3.3750
# 2               0.9375
# 3              -7.3750
# 4               4.2500

# %%
nhl_df.head()
# Out:
#          TeamYear  Win Ratio  Goal Diff Sport
# 0   Avalanche2013      0.634         30   NHL
# 1       Blues2013      0.634         57   NHL
# 2  Blackhawks2013      0.561         47   NHL
# 3        Wild2013      0.524          1   NHL
# 4       Stars2013      0.488          7   NHL

# %%
nhl_df["Goal Diff per Game"]= nhl_df["Goal Diff"]/82

# %%
nhl_df.head()
# Out:
#          TeamYear  Win Ratio  Goal Diff Sport  Goal Diff per Game
# 0   Avalanche2013      0.634         30   NHL            0.365854
# 1       Blues2013      0.634         57   NHL            0.695122
# 2  Blackhawks2013      0.561         47   NHL            0.573171
# 3        Wild2013      0.524          1   NHL            0.012195
# 4       Stars2013      0.488          7   NHL            0.085366

# %%
nhl_diff_max = nhl_df["Goal Diff per Game"].max()

# %%
nhl_diff_min= nhl_df["Goal Diff per Game"].min()

# %%
nba_diff_max =nba_combined_df["Point Diff"].max()

# %%
nba_diff_min = nba_combined_df["Point Diff"].min()

# %%
nfl_diff_max = nfl_merged["Point Diff per Game"].max()

# %%
nfl_diff_min = nfl_merged["Point Diff per Game"].min()

# %%
print(nfl_diff_max)
print(nfl_diff_min)
print(nba_diff_max)
print(nba_diff_min)
print(nhl_diff_max)
print(nhl_diff_min)
# Out:
# 12.0
# -12.5
# 11.629999999999995
# -10.450000000000003
# 1.024390243902439
# -1.3780487804878048

# %%
nba_combined_df.head()
# Out:
#   Season Regular Season or Playoffs          City      Team Conference  \
# 0   2013                    Regular   Los Angeles  Clippers    WESTERN
# 1   2013                    Regular  Golden State  Warriors    WESTERN
# 2   2013                    Regular       Phoenix      Suns    WESTERN
# 3   2013                    Regular    Sacramento     Kings    WESTERN
# 4   2013                    Regular   Los Angeles    Lakers    WESTERN
#
#   Division  Wins  Losses  Win Pct.  Points For  Points Against    ConcatName  \
# 0  PACIFIC    57      25     0.695      107.93          100.95  Clippers2013
# 1  PACIFIC    51      31     0.622      104.26           99.45  Warriors2013
# 2  PACIFIC    48      34     0.585      105.23          102.60      Suns2013
# 3  PACIFIC    28      54     0.341      100.50          103.40     Kings2013
# 4  PACIFIC    27      55     0.329      102.95          109.24    Lakers2013
#
#             Cap  Rank   YearMeanCap  RelativePay Sport  Point Diff
# 0  $69,518,889     22  $67,104,799         103.6   NBA        6.98
# 1  $69,712,825     24  $67,104,799         103.9   NBA        4.81
# 2  $53,234,902      1  $67,104,799          79.3   NBA        2.63
# 3  $53,575,342      2  $67,104,799          79.8   NBA       -2.90
# 4  $99,847,565     30  $67,104,799         148.8   NBA       -6.29

# %%
nba_combined_df["Adjusted PD"] = nba_combined_df["Point Diff"]-nba_diff_min

# %%
nba_combined_df["Relative PD"]= nba_combined_df["Adjusted PD"]/(nba_diff_max-nba_diff_min)

# %%
nba_combined_df.head()
# Out:
#   Season Regular Season or Playoffs          City      Team Conference  \
# 0   2013                    Regular   Los Angeles  Clippers    WESTERN
# 1   2013                    Regular  Golden State  Warriors    WESTERN
# 2   2013                    Regular       Phoenix      Suns    WESTERN
# 3   2013                    Regular    Sacramento     Kings    WESTERN
# 4   2013                    Regular   Los Angeles    Lakers    WESTERN
#
#   Division  Wins  Losses  Win Pct.  Points For  Points Against    ConcatName  \
# 0  PACIFIC    57      25     0.695      107.93          100.95  Clippers2013
# 1  PACIFIC    51      31     0.622      104.26           99.45  Warriors2013
# 2  PACIFIC    48      34     0.585      105.23          102.60      Suns2013
# 3  PACIFIC    28      54     0.341      100.50          103.40     Kings2013
# 4  PACIFIC    27      55     0.329      102.95          109.24    Lakers2013
#
#             Cap  Rank   YearMeanCap  RelativePay Sport  Point Diff  \
# 0  $69,518,889     22  $67,104,799         103.6   NBA        6.98
# 1  $69,712,825     24  $67,104,799         103.9   NBA        4.81
# 2  $53,234,902      1  $67,104,799          79.3   NBA        2.63
# 3  $53,575,342      2  $67,104,799          79.8   NBA       -2.90
# 4  $99,847,565     30  $67,104,799         148.8   NBA       -6.29
#
#    Adjusted PD  Relative PD
# 0        17.43     0.789402
# 1        15.26     0.691123
# 2        13.08     0.592391
# 3         7.55     0.341938
# 4         4.16     0.188406

# %%
nfl_merged["Adjusted PD"] = nfl_merged["Point Diff per Game"]-nfl_diff_min

# %%
nfl_merged["Relative PD"] = nfl_merged["Adjusted PD"]/(nfl_diff_max-nfl_diff_min)

# %%
nfl_merged.head()
# Out:
#            Team  Win Pct  Year  Points For  Points Against  \
# 0  2014Patriots    0.750  2014       468.0           313.0
# 1     2014Bills    0.563  2014       343.0           289.0
# 2  2014Dolphins    0.500  2014       388.0           373.0
# 3      2014Jets    0.250  2014       283.0           401.0
# 4  2014Steelers    0.688  2014       436.0           368.0
#
#    Point Differential      Payroll  Relative Payroll Sport  \
# 0               155.0  132130517.0         96.312633   NFL
# 1                54.0  135589765.0         98.834149   NFL
# 2                15.0  144645040.0        105.434724   NFL
# 3              -118.0  106085353.0         77.327781   NFL
# 4                68.0  138857568.0        101.216117   NFL
#
#    Point Diff per Game  Adjusted PD  Relative PD
# 0               9.6875      22.1875     0.905612
# 1               3.3750      15.8750     0.647959
# 2               0.9375      13.4375     0.548469
# 3              -7.3750       5.1250     0.209184
# 4               4.2500      16.7500     0.683673

# %%
nhl_df["Adjusted PD"]= nhl_df["Goal Diff per Game"]-nhl_diff_min

# %%
nhl_df["Relative PD"]= nhl_df["Adjusted PD"]/(nhl_diff_max-nhl_diff_min)

# %%
nhl_df.head()
# Out:
#          TeamYear  Win Ratio  Goal Diff Sport  Goal Diff per Game  \
# 0   Avalanche2013      0.634         30   NHL            0.365854
# 1       Blues2013      0.634         57   NHL            0.695122
# 2  Blackhawks2013      0.561         47   NHL            0.573171
# 3        Wild2013      0.524          1   NHL            0.012195
# 4       Stars2013      0.488          7   NHL            0.085366
#
#    Adjusted PD  Relative PD
# 0     1.743902     0.725888
# 1     2.073171     0.862944
# 2     1.951220     0.812183
# 3     1.390244     0.578680
# 4     1.463415     0.609137

# %%
nba_point_diff_df = nba_combined_df[["ConcatName","Relative PD"]]

# %%
nba_point_diff_df.head()
# Out:
#      ConcatName  Relative PD
# 0  Clippers2013     0.789402
# 1  Warriors2013     0.691123
# 2      Suns2013     0.592391
# 3     Kings2013     0.341938
# 4    Lakers2013     0.188406

# %%
nba_point_diff_df.rename(columns={"ConcatName":"TeamYear"})
# Out:
#              TeamYear  Relative PD
# 0        Clippers2013     0.789402
# 1        Warriors2013     0.691123
# 2            Suns2013     0.592391
# 3           Kings2013     0.341938
# 4          Lakers2013     0.188406
# 5         Rockets2013     0.679801
# 6       Grizzlies2013     0.544837
# 7       Mavericks2013     0.581975
# 8        Pelicans2013     0.350543
# 9         Thunder2013     0.760417
# 10   Timberwolves2013     0.594203
# 11        Nuggets2013     0.376359
# 12           Jazz2013     0.148551
# 13           Heat2013     0.688859
# 14        Wizards2013     0.530797
# 15        Hornets2013     0.463315
# 16          Hawks2013     0.451540
# 17          Magic2013     0.226902
# 18         Pacers2013     0.672554
# 19          Bulls2013     0.557065
# 20      Cavaliers2013     0.324275
# 21        Pistons2013     0.307518
# 22          Bucks2013     0.102808
# 23        Raptors2013     0.620018
# 24           Nets2013     0.427989
# 25         Knicks2013     0.437500
# 26        Celtics2013     0.270833
# 27          76ers2013     0.000000
# 28          Hawks2014     0.719203
# 29        Wizards2014     0.505888
# ..                ...          ...
# 138  Timberwolves2017     0.574275
# 139       Nuggets2017     0.540308
# 140      Warriors2018     0.737772
# 141      Clippers2018     0.504076
# 142         Kings2018     0.417120
# 143        Lakers2018     0.390399
# 144          Suns2018     0.057971
# 145       Rockets2018     0.586051
# 146      Pelicans2018     0.508152
# 147     Mavericks2018     0.398098
# 148     Grizzlies2018     0.362772
# 149       Nuggets2018     0.703351
# 150       Thunder2018     0.662138
# 151          Jazz2018     0.631793
# 152  Timberwolves2018     0.460145
# 153          Heat2018     0.452899
# 154         Magic2018     0.429801
# 155       Hornets2018     0.444746
# 156       Wizards2018     0.352355
# 157         Hawks2018     0.169384
# 158         Bucks2018     0.890399
# 159        Pacers2018     0.682065
# 160       Pistons2018     0.466486
# 161         Bulls2018     0.134058
# 162     Cavaliers2018     0.036685
# 163       Raptors2018     0.701993
# 164         76ers2018     0.622283
# 165       Celtics2018     0.725543
# 166          Nets2018     0.456522
# 167        Knicks2018     0.094203
#
# [168 rows x 2 columns]

# %%
nhl_point_diff_df = nhl_df[["TeamYear","Relative PD"]]

# %%
nhl_point_diff_df
# Out:
#                TeamYear  Relative PD
# 0         Avalanche2013     0.725888
# 1             Blues2013     0.862944
# 2        Blackhawks2013     0.812183
# 3              Wild2013     0.578680
# 4             Stars2013     0.609137
# 5         Predators2013     0.441624
# 6              Jets2013     0.522843
# 7             Ducks2013     0.862944
# 8            Sharks2013     0.822335
# 9             Kings2013     0.736041
# 10          Coyotes2013     0.497462
# 11          Canucks2013     0.436548
# 12           Flames2013     0.411168
# 13           Oilers2013     0.233503
# 14           Bruins2013     1.000000
# 15        Lightning2013     0.700508
# 16        Canadiens2013     0.629442
# 17        Red Wings2013     0.532995
# 18         Senators2013     0.426396
# 19      Maple Leafs2013     0.446701
# 20         Panthers2013     0.208122
# 21           Sabres2013     0.111675
# 22         Penguins2013     0.786802
# 23          Rangers2013     0.700508
# 24           Flyers2013     0.578680
# 25     Blue Jackets2013     0.649746
# 26         Capitals2013     0.548223
# 27           Devils2013     0.517766
# 28       Hurricanes2013     0.456853
# 29        Islanders2013     0.360406
# ..                  ...          ...
# 152          Sharks2018     0.751269
# 153  Golden Knights2018     0.649746
# 154         Coyotes2018     0.538071
# 155          Oilers2018     0.431472
# 156         Canucks2018     0.441624
# 157           Ducks2018     0.279188
# 158           Kings2018     0.294416
# 159       Predators2018     0.690355
# 160            Jets2018     0.705584
# 161           Blues2018     0.629442
# 162           Stars2018     0.578680
# 163            Wild2018     0.538071
# 164       Avalanche2018     0.598985
# 165      Blackhawks2018     0.426396
# 166       Islanders2018     0.741117
# 167        Capitals2018     0.675127
# 168        Penguins2018     0.715736
# 169      Hurricanes2018     0.670051
# 170    Blue Jackets2018     0.593909
# 171          Flyers2018     0.472081
# 172         Rangers2018     0.421320
# 173          Devils2018     0.390863
# 174       Lightning2018     1.000000
# 175          Bruins2018     0.751269
# 176     Maple Leafs2018     0.827411
# 177       Canadiens2018     0.609137
# 178          Sabres2018     0.461929
# 179        Panthers2018     0.477157
# 180       Red Wings2018     0.350254
# 181        Senators2018     0.299492
#
# [182 rows x 2 columns]

# %%
nfl_point_diff_df = nfl_merged[["Team","Relative PD"]]

# %%
nfl_point_diff_df.rename(columns={"Team":"TeamYear"})
# Out:
#            TeamYear  Relative PD
# 0      2014Patriots     0.905612
# 1         2014Bills     0.647959
# 2      2014Dolphins     0.548469
# 3          2014Jets     0.209184
# 4      2014Steelers     0.683673
# 5       2014Bengals     0.563776
# 6        2014Ravens     0.783163
# 7        2014Browns     0.413265
# 8         2014Colts     0.737245
# 9        2014Texans     0.676020
# 10      2014Jaguars     0.094388
# 11       2014Titans     0.040816
# 12      2014Broncos     0.836735
# 13       2014Chiefs     0.693878
# 14     2014Chargers     0.510204
# 15      2014Raiders     0.002551
# 16      2014Cowboys     0.803571
# 17       2014Eagles     0.698980
# 18       2014Giants     0.459184
# 19     2014Redskins     0.160714
# 20      2014Packers     0.862245
# 21        2014Lions     0.609694
# 22      2014Vikings     0.464286
# 23        2014Bears     0.196429
# 24     2014Panthers     0.420918
# 25       2014Saints     0.451531
# 26      2014Falcons     0.418367
# 27   2014Buccaneers     0.170918
# 28     2014Seahawks     0.867347
# 29    2014Cardinals     0.538265
# ..              ...          ...
# 128       2018Bills     0.242347
# 129        2018Jets     0.234694
# 130      2018Ravens     0.770408
# 131    2018Steelers     0.683673
# 132      2018Browns     0.426020
# 133     2018Bengals     0.288265
# 134      2018Texans     0.729592
# 135       2018Colts     0.737245
# 136      2018Titans     0.528061
# 137     2018Jaguars     0.329082
# 138      2018Chiefs     0.877551
# 139    2018Chargers     0.762755
# 140     2018Broncos     0.459184
# 141     2018Raiders     0.058673
# 142     2018Cowboys     0.548469
# 143      2018Eagles     0.558673
# 144    2018Redskins     0.311224
# 145      2018Giants     0.400510
# 146       2018Bears     0.862245
# 147     2018Vikings     0.558673
# 148     2018Packers     0.448980
# 149       2018Lions     0.418367
# 150      2018Saints     0.895408
# 151     2018Falcons     0.487245
# 152    2018Panthers     0.494898
# 153  2018Buccaneers     0.336735
# 154        2018Rams     0.875000
# 155    2018Seahawks     0.716837
# 156       201849ers     0.272959
# 157   2018Cardinals     0.000000
#
# [158 rows x 2 columns]

# %%
all_sports_point_diff_df= pd.concat([nba_point_diff_df,nfl_point_diff_df,nhl_point_diff_df])
# Out:
# /Users/henrynahmad/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
